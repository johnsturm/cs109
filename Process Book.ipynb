# %% [markdown]
# # Import Libraries

# %%
import requests
import json
import re
import math
import random
import time
import unicodedata
import pandas as pd
import matplotlib.pyplot as plt
import HTMLParser
import urllib
from pattern import web
import numpy as np
import datetime
import dateutil
import sklearn
from sklearn.neighbors import KNeighborsRegressor
from sklearn.cross_validation import KFold
from sklearn.linear_model import LogisticRegression
import itertools
from collections import defaultdict
from operator import itemgetter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import MultinomialNB
import operator
import sklearn.svm as sksvm

from   sklearn.feature_extraction.text import CountVectorizer
from   sklearn.cross_validation        import train_test_split
from   sklearn.naive_bayes             import MultinomialNB

import sklearn.linear_model            as     sklm
import sklearn.tree                    as     sktr
import sklearn.cross_validation        as     cv

# %matplotlib inline

html_parser = HTMLParser.HTMLParser()



#CS109's remove_border code:
def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %% [markdown]
# # Section 1 - Data Collection

# %% [markdown]
# ## 1.1 Scrape Project Titles

# %% [markdown]
# We found this site, Kickspy, from which you can get all the titles of kickstarter projects. In this section, we're scraping from that site and  getting all the titles of projects.

# %%
def cat_string(categories):
    s = ""
    for c in categories:
        s += "&Categories=" + str(c)
    return s

def make_url(year, month, day, categories):
    year = str(year)
    month = str(month)
    day = str(day)
    
    return "http://www.kickspy.com/projects/find?Keywords=&Settings.ExpandStatus=true&AnyStatus=true&Settings.ExpandCategories=true" + cat_string(categories) + "&Settings.ExpandDates=true&StartedAfter=" + year + "%2F" + month + "%2F" + day + "&StartedBefore=" + year + "%2F" + month + "%2F" + day + "&SortBy=0"

def get_titles(year, month, day):
    #url = "http://www.kickspy.com/projects/find?Keywords=&Settings.ExpandStatus=true&AnyStatus=true&AllCategories=true&Settings.ExpandDates=true&StartedAfter=" + year + "%2F" + month + "%2F" + day + "&StartedBefore=" + year + "%2F" + month + "%2F" + day + "&SortBy=0"
    
    titles = set()
    
    text = requests.get(make_url(year, month, day, [j for j in range(14)])).text[60928:]
    for line in text.split('\n'):
        if "<h3>" in line:
            l = re.findall(r'">(.*)<\/a><\/h3>', text)
            titles.update([unicodedata.normalize('NFKD', j.strip()).encode('ascii','ignore') for j in l])
        
    text = requests.get(make_url(year, month, day, [j + 14 for j in range(17)])).text[60928:]
    for line in text.split('\n'):
        if "<h3>" in line:
            l = re.findall(r'">(.*)<\/a><\/h3>', text)
            titles.update([unicodedata.normalize('NFKD', j.strip()).encode('ascii','ignore') for j in l])

    text = requests.get(make_url(year, month, day, [j + 31 for j in range(31)])).text[60928:]
    for line in text.split('\n'):
        if "<h3>" in line:
            l = re.findall(r'">(.*)<\/a><\/h3>', text)
            titles.update([unicodedata.normalize('NFKD', j.strip()).encode('ascii','ignore') for j in l])
            
    time.sleep(2)
        
    return titles

def all_titles():
    years = [2009, 2010, 2011, 2012, 2013]
    months = [i + 1 for i in range(12)]
    
    all_titles = []
    
    for y in years:
        for m in months:
            print m
            days = []
            if m in [1, 3, 5, 7, 8, 10, 12]:
                days = [1 + i for i in range(31)]
            elif m in [4,6,9,11]:
                days = [1 + i for i in range(30)]
            else:
                days = [1+i for i in range(28)]
            for d in days:
                all_titles.extend(get_titles(y, m, d))
    
    return all_titles

# %%
# just a test to make sure our functions worked
year = 2013
month = 11
day = 12
print make_url(year, month, day, [j + 1 for j in range(13)])
print make_url(year, month, day, [j + 14 for j in range(17)])
print make_url(year, month, day, [j + 31 for j in range(20)])

# %%
titles_all = all_titles()

# %%
titles_all.reverse()

# %% [markdown]
# We'll want these titles later to scrape the project data from another site, given their titles.
# So save this all to a text file that we can access later, then do some formatting

# %%
f = open("titles_all.txt", "w")
for t in titles_all:
    f.write(t)
    f.write("\n")
f.close()

# %%
# open the text file list of kickstarter titles, convert formatting
f = open("titles_all.txt", "r")
all_titles = f.read().split("\n")
f.close()

print len(all_titles)
# Out:
# 121279

# %%
#convert titles to normal text format
for i, title in enumerate(all_titles):
    all_titles[i] = unicode(html_parser.unescape(title))

# %% [markdown]
# ## 1.2 Scrape Project Information

# %% [markdown]
# Given a project's title, you can scrape its project information from kickstarter.
#
# This information includes stuff like: project start date, end date, location, goal amount, name of user, title of project, blurb of project, and a whole bunch more. This are most of the fields that we'll want in order to make our predictions.

# %%
# here are some special functions (some of them hack-ish) to help us get around a few formatting bugs in the next section of code
# not super interesting

def dict_iterator(my_dict):
    for key, value in my_dict.iteritems():
        if type(value)==list:
            for item in value:
                new_dict = dict_iterator(item)
                my_dict[key] = new_dict
        if type(value)==dict:
            new_dict = dict_iterator(value)
            my_dict[key] = new_dict
        if type(value)==unicode:
            if 'saal_tucker_sturm_zimble' in value:
                value = value.replace('saal_tucker_sturm_zimble','"')
                my_dict[key] = value
    return my_dict

def tm_remover(title):
    words = []
    for word in title.split(' '):
        if 'TM' not in word:
            words.append(word)
    return " ".join(words)
            
def alt_project_fetch(title):
    url_endings = []
    new_dicts = []
    url = 'http://www.kickspy.com/projects/find?Keywords='+title+'&Settings.ExpandStatus=true&AnyStatus=true&AllCategories=true&SortBy=0'
    try:
        text = requests.get(url).text
    except ValueError:
        return None
    for line in text.split('\n'):
        if "0 results found" in line:
            if "TM" in title:
                return alt_project_fetch(tm_remover(title))
            else:
                return None
        elif "<h3>" in line:
            url_ending = line.split('href="',1)[1]
            url_ending = url_ending.split('">',1)[0]
            url_endings.append(url_ending)
    if url_endings==[]:
        return None
    for url_ending in url_endings:
        url_2 = "http://www.kickstarter.com/" + url_ending
        try:
            text_2 = requests.get(url_2).text
        except ValueError:
            return None
        for line in text_2.split('\n'):
            if 'window.current_project' in line:
                data = unicode(html_parser.unescape(line))
                data = data.split('window.current_project = "',1)[1]
                data = data.split('";')[0]
                data = str(data)
                data = data.replace('\\"','\\saal_tucker_sturm_zimble')
                data = data.replace('\\','')
                try:
                    data = json.loads(data)
                except ValueError:
                    continue
                data = dict_iterator(data)
                new_dicts.append(data)
    return new_dicts

# %%
# function to get info (from kickstarter) about all the projects associated to titles in a list of titles
def get_projects(titles):
    error_titles=[]
    base_url = "http://www.kickstarter.com/projects/search.json"
    fields = ['creator_id', 'creator_name', 'creator_slug',
              'project_id', 'project_name', 'project_slug', 'blurb', 'category',
              'currency', 'goal', 'pledged', 'backers_count',
              'launched_at', 'deadline', 'last_state_change', 'state',
              'location_id', 'location_name', 'country',
              'project_url', 'creator_url']
    projects = dict((field, []) for field in fields)
    
    for i, title in enumerate(titles):
        if i%100 == 0:
            print i
        try:
            data = requests.get(base_url, params = {'search': '', 'term': title}).json()['projects']
        except ValueError:
            data = alt_project_fetch(title)
            if data == None:
                error_titles.append(title)
                continue
            
        if len(data) == 0:
            data = alt_project_fetch(title)
            if data == None:
                error_titles.append(title)
                continue
            data = [data]
            
            
        for project in data:
            if project['id'] not in projects['project_id']:
                
                
                try:
                    projects['creator_id'].append( project['creator']['id'] )
                except KeyError:
                    projects['creator_id'].append( '' )
                    
                try:
                    projects['creator_name'].append( project['creator']['name'].encode('utf-8') )
                except KeyError:
                    projects['creator_name'].append( '' )
                    
                try:
                    projects['creator_slug'].append( project['creator']['slug'].encode('utf-8') )
                except KeyError:
                    projects['creator_slug'].append( '' )
                
                try:
                    projects['project_id'].append( project['id'] )
                except KeyError:
                    projects['project_id'].append( '' )
                    
                try:
                    projects['project_name'].append( project['name'].encode('utf-8') )
                except KeyError:
                    projects['project_name'].append( '' )
                    
                try:
                    projects['project_slug'].append( project['slug'].encode('utf-8') )
                except KeyError:
                    projects['project_slug'].append( '' )
                    
                try:
                    projects['blurb'].append( project['blurb'].encode('utf-8') )
                except KeyError:
                    projects['blurb'].append( '' )
                    
                try:
                    projects['category'].append( project['category']['name'].encode('utf-8') )
                except KeyError:
                    projects['category'].append( '' )
                    
                try:
                    projects['currency'].append( project['currency'].encode('utf-8') )
                except KeyError:
                    projects['currency'].append( '' )
                
                try:
                    projects['goal'].append( project['goal'] )
                except KeyError:
                    projects['goal'].append( '' )
                    
                try:
                    projects['pledged'].append( project['pledged'] )
                except KeyError:
                    projects['pledged'].append( '' )
                
                try:
                    projects['backers_count'].append( project['backers_count'] )
                except KeyError:
                    projects['backers_count'].append( '' )
                    
                try:
                    projects['launched_at'].append( project['launched_at'] )
                except KeyError:
                    projects['launched_at'].append( '' )
                    
                try:
                    projects['deadline'].append( project['deadline'] )
                except KeyError:
                    projects['deadline'].append( '' )
                    
                try:
                    projects['last_state_change'].append( project['state_changed_at'] )
                except KeyError:
                    projects['last_state_change'].append( '' )
                    
                try:
                    projects['state'].append( project['state'].encode('utf-8') )
                except KeyError:
                    projects['state'].append( '' )
                    
                try:
                    projects['location_id'].append( project['location']['id'] )
                except KeyError:
                    projects['location_id'].append( '' )
                    
                try:
                    projects['location_name'].append( project['location']['name'].encode('utf-8') )
                except KeyError:
                    projects['location_name'].append( '' )
                    
                try:
                    projects['country'].append( project['country'].encode('utf-8') )
                except KeyError:
                    projects['country'].append( '' )
                
                try:
                    projects['project_url'].append( project['urls']['web']['project'].encode('utf-8') )
                except KeyError:
                    projects['project_url'].append( '' )
                
                try:
                    projects['creator_url'].append( project['creator']['urls']['web']['user'].encode('utf-8') )
                except KeyError:
                    projects['creator_url'].append( '' )
            
    return error_titles, pd.DataFrame(projects)

# %% [markdown]
# Note that for some of the titles, we were unable to find projects. For this reason we have a list of errors that we're also saving. More on this in a few cells.

# %%
# run the big function we made: get info about all the projects, save it to a csv

project_errors, all_projects = get_projects(all_titles)

all_projects.to_csv('all_project_data.csv')

f_n = open("project_errors.txt", "w")
for error in project_errors:
    error = error.encode('ascii','ignore')
    f_n.write(error)
    f_n.write("\n")
f_n.close()

# %%
#this function outputs a modified copy of an inputted data frame in which the 
#values in the selected fields are converted from timestamps to the string-version of datetimes

def time_to_datetimes(input_df, fields):
    df = input_df.copy()
    for field in fields:
        df[field] = df[field].astype(str)
        for i, time in enumerate(df[field]):
            df[field][i] = str(datetime.datetime.fromtimestamp(float(time)))
    return df

# %%
#convert the csv of projects to having dates in datetime format, save to new csv
all_projects = pd.read_csv('all_project_data.csv')
time_fields = ['launched_at', 'deadline', 'last_state_change']
all_projects_time = time_to_datetimes(all_projects, time_fields)
all_projects_time.to_csv('all_project_data_time.csv')

# %%
# compare the lengths of the titles list and the projects data frame, so that we can see how many erros we had

all_projects= pd.read_csv('all_project_data_time.csv')
print len(all_titles)
print len(all_projects.project_id)
#print all_projects.creator_id.nunique()
# Out:
# 121279
# 120099

# %% [markdown]
# Note that we have fewer projects than we had project titles (121279 vs 120009) ... suspicious.
# When we go and look at the project titles that don't show up in our projects dataframe, we find that they refer to projects whose titles have been changed at some point during the kickstarter funding period. So either we already have these under their final titles, or we'll missing them entirely. Either way, it's less than a percent of our data, and there seems no reason to think that it's going to affect our predictions - so we're OK.

# %% [markdown]
# ## 1.3 Scrape User Data

# %%
def get_user_data(titles_df):    
    fields = ['creator_name', 'creator_slug',
              'projects_created', 'projects_backed','creator_id', 'location', 'date_joined',
              'facebook_link','twitter_link', 'creator_url']
    individual_users = dict((field, []) for field in fields)
    missing_created_project_data = []
    missing_backed_project_data = []
    url_list = all_projects['creator_url'].unique()
    
    #For John
    for i,url in enumerate(url_list[25986: 51972]):
    
    #For Eli
    #for i,url in enumerate(url_list[51972: 77958]):
    
    #For Aaron
    #for i,url in enumerate(url_list[77958: ]):
    
    #For Jake
    #for i,url in enumerate(url_list[: 25986]):
        if i%1000 == 0:
            print i
        # Define Variables
        projects_created_name = []
        projects_created_id = []
        projects_created_missing = []
        projects_backed_url = []
        projects_backed_id = []
        projects_backed_missing = []
        projects_created = ''
        projects_backed = ''
        location = ''
        date_joined = ''
        facebook_link = ''
        twitter_link = ''

        # Get userpage data
        usr_df = titles_df[titles_df.creator_url == url]
        xml = requests.get(url).text
        dom = web.Element(xml)
        
        # Get data from project dataframe
        creator_slug = usr_df.creator_slug.unique()
        creator_slug = creator_slug[0]
        creator_name = usr_df.creator_name.unique()
        creator_name = creator_name[0]
        creator_id = usr_df.creator_id.unique()
        creator_id = creator_id[0]

        # Get the projects the user created
        for project in usr_df.project_name:
            project = project.decode('utf-8')
            projects_created_name.append(project)
        for subset in dom.by_class("profile_created_projects"):
            for item in subset.by_class("project_name"):
                project = item.content.replace('\n','')
                project = unicode(html_parser.unescape(project))
                if project not in projects_created_name:
                    projects_created_missing.append( project )
                    missing_created_project_data.append( project )
        for project_id in usr_df.project_id:
            project_id = int( project_id )
            projects_created_id.append( str(project_id) )
        projects_created = ','.join(projects_created_id)
        
        
        # Get the projects the user backed
        for subset in dom.by_class("mobius"):
            for subdict in subset.by_tag('a'):
                base_url = 'http://www.kickstarter.com'
                projects_backed_url.append( base_url + subdict.attrs['href'] )
        for project_backed_url in projects_backed_url:
            backed_id = titles_df.project_id[titles_df.project_url == project_backed_url]
            if len(backed_id) == 0:
                backed_id = titles_df.project_id[titles_df.project_url == project_backed_url+'?ref=live']
            if len(backed_id) == 0:
                backed_id = 0
                missing_backed_project_data.append( project_backed_url )
            backed_id = backed_id.iloc[0,:]
            projects_backed_id.append( str(backed_id) )
        projects_backed = ','.join(projects_backed_id)
    
        #Get Location
        for city in dom.by_class("location"):
            city = city.content.replace('\n','')
            city = unicode(html_parser.unescape(city))
            location = city.encode('utf-8')
    
        # Get User Join Date
        for join_date in dom.by_class("joined"):
            join_date = join_date.content.replace('\n','')
            join_date = join_date.replace('Joined','')
            join_date = unicode(html_parser.unescape(join_date))
            date_joined = join_date.encode('utf-8')
            
        #Access A Seperate Dom for the Bio Data    
        for line in dom.by_class('remote_modal_dialog'):
            bio_url = 'http://www.kickstarter.com'+ line.attrs['href']
            bio_xml = requests.get(bio_url).text
            bio_dom = web.Element(bio_xml)
            for subset in bio_dom.by_class('menu-submenu'):
                for link in subset('a'):
                    my_link = link.attrs['href']
                    if 'facebook' in my_link:
                        facebook_link = my_link
                    if 'twitter' in my_link:
                        twitter_link = my_link
        
        #Update the Dictionary
        individual_users['creator_url'].append( url )
        individual_users['creator_slug'].append( creator_slug )
        individual_users['creator_name'].append( creator_name )
        individual_users['creator_id'].append( creator_id )
        individual_users['projects_created'].append( projects_created )                
        individual_users['projects_backed'].append( projects_backed )
        individual_users['location'].append( location )
        individual_users['date_joined'].append( date_joined )
        individual_users['facebook_link'].append( facebook_link )
        individual_users['twitter_link'].append( twitter_link )
        
    return missing_created_project_data, missing_backed_project_data, pd.DataFrame(individual_users)

# %%
missing_created_project_data, missing_backed_project_data, user_df = get_user_data(all_projects)

#Put your name in the YOURNAMEHERE so the docs will be different
user_df.to_csv('User_data_johnsturm.csv')
f = open("missing_created_project_johnsturm.txt", "w")
for missing_created_project in missing_created_project_data:
    missing_created_project = missing_created_project.encode('ascii','ignore')
    f.write(missing_created_project)
    f.write("\n")
f.close()
f = open("missing_backed_project_johnsturm.txt", "w")
for missing_backed_project in missing_backed_project_data:
    missing_backed_project = missing_backed_project.encode('ascii','ignore')
    f.write(missing_backed_project)
    f.write("\n")
f.close()

# %%
print all_projects.iloc[0,:]
# Out:
# Unnamed: 0                                                           0
# Unnamed: 0.1                                                         0
# backers_count                                                        0
# blurb                hip-hopumentary- a scored documentary tracing ...
# category                                                   Documentary
# country                                                             US
# creator_id                                                   961594991
# creator_name                                              Tre Matthews
# creator_slug                                             tremoneybaggs
# creator_url           http://www.kickstarter.com/profile/tremoneybaggs
# currency                                                           USD
# deadline                                           2014-01-09 19:29:02
# goal                                                              4500
# ...

# %%
all_projects['creator_name']
# Out:
# 0               Tre Matthews
# 1                 Tara Dafoe
# 2               Chris Crosby
# 3               Gabe Wallace
# 4               Justin Young
# 5                Shana Lloyd
# 6                    Ien Chi
# 7       Jessica Marie Curtis
# 8             Red Montgomery
# 9                  Tim Craig
# 10        Community Food Lab
# 11     Fire in the Hole, LLC
# 12                  Zark LLC
# 13    C Enterprise (UK) Ltd.
# 14             Serena Winter
# ...
# 120084          Earl Scioneaux
# 120085    Accidental Nostalgia
# 120086    Accidental Nostalgia
# 120087             Jared Hoffa
# 120088        Dereck Blackburn
# 120089            Haden & Rose
# 120090                 kmikeym
# 120091             laura kicey
# 120092          Brendan Mackie
# 120093          We Make a Book
# 120094                   Coley
# 120095             Dan Phiffer
# 120096                darkpony
# 120097              videothing
# 120098              Perry Chen
# ...

# %%
#After combining the txt and csv files
f = open("Overall_missing_created_projects.txt", "r")
overall_missing_created_projects = f.read().split("\n")
f.close()
f = open("Overall_missing_backed_projects.txt", "r")
Overall_missing_backed_projects = f.read().split("\n")
f.close()
all_users= pd.read_csv('overall_user_data.csv')

# %% [markdown]
# ## 1.4 Try 2 for Network data

# %%
def get_just_network_data(titles_df): 
    fields = ['projects_created', 'projects_backed','creator_id']
    individual_users = dict((field, []) for field in fields)
    url_list = all_projects['creator_url'].unique()
    base_url = 'http://www.kickstarter.com'
    for i,url in enumerate(url_list[:50000]):
        if i%1000 == 0:
            print i
        
        # Define Variables
        projects_created_name = []
        projects_created_id = []
        projects_backed_url = []
        projects_backed_id = []
        projects_created = ''
        projects_backed = ''

        # Get userpage data
        usr_df = titles_df[titles_df.creator_url == url]
        xml = requests.get(url).text
        dom = web.Element(xml)
        
        #Get ID
        creator_id = usr_df.creator_id.unique()
        creator_id = str(creator_id[0])
        
        # Get the projects the user created
        for project_id in usr_df.project_id:
            projects_created_id.append( str(project_id) )
        projects_created = ','.join(projects_created_id)
        
        # Get the projects the user backed
        for subset in dom.by_class("mobius"):
            for subdict in subset.by_tag('a'):
                projects_backed_url.append( base_url + subdict.attrs['href'] )
        for project_backed_url in projects_backed_url:
            try:
                backed_id = titles_df.project_id[titles_df.project_url == project_backed_url].values[0]
            except IndexError:
                try:
                    backed_id = titles_df.project_id[titles_df.project_url == project_backed_url+'?ref=live'].values[0]
                except IndexError:
                    continue
            
            projects_backed_id.append( str(backed_id) )
        projects_backed = ','.join(projects_backed_id)
        individual_users['creator_id'].append( creator_id )
        individual_users['projects_created'].append( projects_created )                
        individual_users['projects_backed'].append( projects_backed )
    return pd.DataFrame(individual_users)

# %%
user_network_df = get_just_network_data(all_projects)

# %% [markdown]
# ## 1.5 Combine User and Project Data

# %%
def update_projects_with_users(project_df, user_df):
    project_df = project_df.copy()
    user_df = user_df.copy()
    project_df['facebook'] = project_df['creator_id'].map(lambda x: 0)
    project_df['twitter'] = project_df['creator_id'].map(lambda x: 0)
    project_df['creator_location'] = project_df['creator_id'].map(lambda x: 'string')
    project_df['creator_joined'] = project_df['creator_id'].map(lambda x: 'string')
    for i in range(len(project_df)):
        creator_join_date = user_df.date_joined[user_df.creator_id == project_df.creator_id[i]]
        creator_join_date = creator_join_date.iloc[0]
        if type(creator_join_date) != type(0.):
            creator_join_date = creator_join_date.split('"',2)[1]
            if 'T' in creator_join_date:
                date, time = creator_join_date.split('T',)
                time = time.split('-',)[0]
                creator_join_date = date+' '+time
                creator_join_date = pd.to_datetime(creator_join_date)
                project_df.creator_joined[i] = creator_join_date
            else:
                project_df.creator_joined[i] = creator_join_date
        location = user_df.location[user_df.creator_id == project_df.creator_id[i]]
        location = location.iloc[0]
        project_df.creator_location[i] = location
        twitter = user_df.twitter_link[user_df.creator_id == project_df.creator_id[i]]
        twitter = twitter.iloc[0]
        facebook = user_df.facebook_link[user_df.creator_id == project_df.creator_id[i]]
        facebook = facebook.iloc[0]
        if type(facebook) == type(0.):
            project_df.facebook[i] = 0
        else:
            project_df.facebook[i] = 1
        if type(twitter) == type(0.):
            project_df.twitter[i] = 0
        else:
            project_df.twitter[i] = 1
        if i%1000 == 0:
            print i
    return project_df

# %%
final_project_df = update_projects_with_users(all_projects, all_users)

# %%
final_project_df = final_project_df.drop('Unnamed: 0',1)
final_project_df = final_project_df.drop('Unnamed: 0.1',1)

# %%
final_project_df.iloc[5,:]

# %%
final_project_df.to_csv('final_project_data.csv')

# %% [markdown]
# ## 1.6 Date Time Manipulations

# %%
all_projects= pd.read_csv('final_project_data.csv',index_col=0)

# %%
def add_project_length(project_df):
    project_df = project_df.copy()
    try:
        project_lengths = [float((dateutil.parser.parse(project_df['deadline'][i]) - dateutil.parser.parse(time)).days) for i, time in enumerate(project_df['launched_at'])]
    except ValueError:
        project_lengths = float('NaN')
    joined_before_created = []
    j=0
    for i, time in enumerate(project_df['launched_at']):
        try:
            diff = (dateutil.parser.parse(time) - dateutil.parser.parse(project_df['creator_joined'][i])).days
            joined_before_created.append(float(diff))
        except ValueError:
            joined_before_created.append(float('NaN'))
    project_df['project_length'] = project_lengths
    project_df['joined_before_created'] = joined_before_created
    
    return project_df

# %%
all_projects = add_project_length(all_projects)

# %%
print all_projects.iloc[0,:]

# %%
all_projects.to_csv('final_project_data.csv')

# %% [markdown]
# ## 1.7 Convert to Dollars

# %% [markdown]
# Here we're converting all the different currency values to dollars so that they are comparable. We're using the nominal exchange rate as a proxy for real exchange rate, but they should be similar for the 'developed nations' in which the projects happen to be.

# %%
all_projects = pd.read_csv('final_project_data.csv',index_col = 0)

# %%
def convert_to_dollars(project_df):
    converted_value = []
    for i in range(len(project_df)):
        if project_df.currency[i] == 'USD':
            converted_value.append(project_df.goal[i])
        elif project_df.currency[i] == 'CAD':
            convert_goal = float(project_df.goal[i]*0.94)
            converted_value.append(convert_goal)
        elif project_df.currency[i] == 'GBP':
            convert_goal = float(project_df.goal[i]*1.64)
            converted_value.append(convert_goal)
        elif project_df.currency[i] == 'NZD':
            convert_goal = float(project_df.goal[i]*0.83)
            converted_value.append(convert_goal)
        elif project_df.currency[i] == 'AUD':
            convert_goal = float(project_df.goal[i]*0.92)
            converted_value.append(convert_goal)
    project_df['goal_dollars'] = converted_value
    return project_df

# %%
all_projects = convert_to_dollars(all_projects)

# %%
all_projects.to_csv('final_project_data.csv')

# %% [markdown]
# ## 1.8 Consolodate links

# %%
all_projects = pd.read_csv('final_project_data.csv',index_col = 0)

# %%
def add_website_overall(df):
    website = []
    for i in range(len(df)):
        if df.facebook[i] == 0 and df.twitter[i] == 0:
            website.append('neither')
        elif df.facebook[i] == 0 and df.twitter[i] == 1:
            website.append('twitter')
        elif df.facebook[i] == 1 and df.twitter[i] == 0:
            website.append('facebook')
        elif df.facebook[i] == 1 and df.twitter[i] == 1:
            website.append('both')
    df['website_overall'] = website
    return df

# %%
all_projects = add_website_overall(all_projects)

# %%
all_projects.to_csv('final_project_data.csv')

# %% [markdown]
# ## 1.9 Upload All Needed Data

# %%
f = open("titles_all.txt", "r")
all_titles = f.read().split("\n")
f.close()
f = open("project_errors.txt", "r")
project_errors = f.read().split("\n")
f.close()
f = open("Overall_missing_created_projects.txt", "r")
overall_missing_created_projects = f.read().split("\n")
f.close()
f = open("Overall_missing_backed_projects.txt", "r")
Overall_missing_backed_projects = f.read().split("\n")
f.close()
all_users= pd.read_csv('overall_user_data.csv')
all_projects= pd.read_csv('final_project_data.csv',index_col=0)

# %%
print len(all_projects)
print all_projects.iloc[10,:]
# Out:
# 120099
# backers_count                                                           35
# blurb                    Promoting local food systems, booklet-style! S...
# category                                                              Food
# country                                                                 US
# creator_id                                                      2021830921
# creator_name                                            Community Food Lab
# creator_slug                                                           NaN
# creator_url                  http://www.kickstarter.com/profile/2021830921
# currency                                                               USD
# deadline                                               2013-12-20 19:19:30
# goal                                                                  6500
# last_state_change                                      2013-11-20 19:19:30
# ...

# %% [markdown]
# ## Blurb Analysis

# %%
all_projects = pd.read_csv('final_project_data.csv', index_col=0)
all_projects = all_projects[all_projects['state'] != 'live']
all_projects = all_projects[all_projects['state'] != 'cancelled']
all_projects['success'] = all_projects.apply(lambda row: int(row['pledged'] - row['goal'] > 0), axis=1)

# %%
def separate_by_field(df, field):
    groups = df.groupby(field)
    
    by_success    = groups.aggregate({'success': np.mean})
    by_success    = by_success.sort(columns='success')
    success       = by_success.values
    success_index = by_success.index.values
    
    by_size       = groups.aggregate({'success': len})
    by_size       = by_size.ix[by_success.index]
    size          = by_size.values
    size_index    = by_size.index.values
    
    by_pledge     = groups.aggregate({'pledged': sum})
    by_pledge     = by_pledge.ix[by_success.index]
    pledge          = by_pledge.values
    pledge_index    = by_pledge.index.values
    
    fig = plt.figure(figsize=(28, 6))
    ax  = fig.add_subplot(1,1,1)
    
    ax.bar(            [i      for i in range(len(success))], success, color='c')
    ax.set_xticks(     [i + .5 for i in range(len(success))])
    ax.set_xticklabels(success_index, rotation='vertical')
    
    plt.show()

    fig = plt.figure(figsize=(28, 6))
    ax = fig.add_subplot(1,1,1)
    
    ax.bar(       [i      for i in range(len(size))], size, color='orange')
    ax.set_xticks([i + .5 for i in range(len(size))])
    ax.set_xticklabels(size_index, rotation='vertical')
    
    plt.show()
    
    fig = plt.figure(figsize=(28, 6))
    ax = fig.add_subplot(1,1,1)
    
    ax.bar(       [i      for i in range(len(by_pledge))], pledge, color='g')
    ax.set_xticks([i + .5 for i in range(len(by_pledge))])
    ax.set_xticklabels(pledge_index, rotation='vertical')
    
    plt.show()

# %%
separate_by_field(all_projects, 'category')
separate_by_field(all_projects, 'currency')

# %%
def make_text(row, columns):
    text = ''+str(row['blurb'])
    for c in columns:
        ctext = c
        if c == 'category':
            ctext = "l".join(str(row[c]).split(" "))
        text += " " + " ".join([str(ctext) + "X" + str(word) for word in str(row[c]).split(" ")])
    return text

def multiply_by_cat(row, b):
    cat = "l".join(str(row['category']).split(" "))
    return " ".join([cat + "X" + word for word in str(row[b]).split(" ")])

def exclude(df, field, set_avoid):
    ans = [1 for i in range(len(df[field].values))]
    df = df
    for avoid in set_avoid:
        df = df[df[field] != avoid]
    return df

# %%
test_projects = pd.read_csv ('test_projects.csv', index_col=0)

# %%
# Defining Cost Functions
def log_likelihood(clf, x, y):
    logPs = clf.predict_log_proba(x)
    return sum([logPs[i][1] for i in range(len(y)) if y[i] == 1]) + sum([logPs[i][0] for i in range(len(y)) if y[i] == 0])

# Utilities for splitting up the dataframes into test and train sets
def gen_random(val):
    if random.random() < val:
        return False
    else:
        return True
    
def disjoint_sets(length, proportion=.25):
    include = [gen_random(proportion) for i in range(length)]
    exclude = [not(i) for i in include]
    return include, exclude

def prelim_split(df, field, proportion=.25):
    y='success'
    i, e = disjoint_sets(len(df), proportion)
    train = df[i]
    test = df[e]
    
    x = df[field]
    y = df['success']
    
    xtrain = train[field]
    xtest_final = test[field]
    ytrain = train['success']
    ytest_final = test['success']
    
    return x, y, xtrain, ytrain, xtest_final, ytest_final

def make_xy(x, y, vectorizer=None):
    text = x
    
    if vectorizer == None:
        vectorizer = CountVectorizer(min_df=0)

    vectorizer.fit(text)
    x = vectorizer.transform(text)
    #X = X.toarray()
    
    return x, y

# Utilities for plotting the predictions/calibration of a model
def ysigma(frac, n):
    return math.sqrt(frac*(1.0 - frac)/n)

def calibration_plot(clf, X, Y):
    nbins = 30
    proba = [row[1] for row in clf.predict_proba(X)]
    
    df        = pd.DataFrame({"proba": proba, "label": Y})
    df["bin"] = df.apply(lambda x: math.floor(x['proba'] * nbins), axis=1)
    
    bins      = df.groupby("bin")
    observed  = bins['label'].aggregate(np.mean).values
    predicted = bins['proba'].aggregate(np.mean).values
    bin_size  = bins['label'].aggregate(len).values
    
    sigmas    = [2*ysigma(observed[i], bin_size[i]) for i in range(len(bin_size))] # 95% confidence interval
    
    plt.errorbar(predicted, observed, yerr=np.vstack([sigmas, sigmas]))
    plt.plot([0,1], [0,1], color="r")
    plt.show()
    
    plt.hist(proba, color='orange')
    plt.show()

def train_score_display(vectorizer, clf, x, xtrain, ytrain, xtest, ytest, fit_params={}):
    vectorizer.fit(x)
    xtrain_v = vectorizer.transform(xtrain)
    xtest_v = vectorizer.transform(xtest)
    
    if 'weight' in fit_params:
        clf.fit(xtrain_v, ytrain, weight=fit_params['weight'])
    else:
        clf.fit(xtrain_v, ytrain)
    
    score = clf.score(xtest_v, ytest)
    calibration_plot(clf, xtest_v, ytest)
    
    return vectorizer, clf

# %%
# This is the code for the random exploration of the parameter space

def mult_dict(d, s):
    ans = {}
    for key in d.keys():
        ans[key] = d[key] * s
    return ans

def test_precision(params, sigmas, precision):
    for key in params.keys():
        target = params[key] * precision / 2.0
        if sigmas[key] * 2 > target:
            return False
    return True
        
def random_move(params, sigmas):
    ans = {}
    for key in params.keys():
        if random.random() < .5:
            ans[key] = -1
            while ans[key] <= 0:
                ans[key] = params[key] + random.gauss(0, sigmas[key])
        else:
            ans[key] = params[key]
            
    if params == ans:
        return random_move(params, sigmas)
    return ans

def random_optimization(model, params, sigmas, xtrain, ytrain, precision = .1):
    best_params = params
    i = 0
    
    while not test_precision(best_params, sigmas, precision):
        best_score  = model(best_params, xtrain, ytrain)
        new_params = random_move(best_params, sigmas)
        new_score  = model(new_params, xtrain, ytrain)
        
        if new_score > best_score:
            best_params = new_params
        else:
            sigmas = mult_dict(sigmas, .9)
        
        i += 1
        if i % 10 == 1:
            print i, best_params, best_score, sigmas
            
    return best_params, best_score

# %%
def nb_classifier(params, xtrain, ytrain):
    vectorizer = CountVectorizer(min_df = params['min_df'])
    vectorizer.fit(xtrain)
    X, Y = make_xy(xtrain, ytrain, vectorizer)
    clf = MultinomialNB(alpha = params['alpha'])
    return np.mean(cv.cross_val_score(clf, X, Y, scoring=log_likelihood))

def log_classifier(params, xtrain, ytrain):
    vectorizer = CountVectorizer(min_df = params['min_df'])
    vectorizer.fit(xtrain)
    X, Y = make_xy(xtrain, ytrain, vectorizer)
    clf = sklm.LogisticRegression(C=params['C'])
    return np.mean(cv.cross_val_score(clf, X, Y, scoring=log_likelihood))

def dt_classifier(params, xtrain, ytrain):
    vectorizer = CountVectorizer(min_df = params['min_df'])
    vectorizer.fit(xtrain)
    X, Y = make_xy(xtrain, ytrain, vectorizer)
    clf =  sktr.DecisionTreeClassifier()
    return np.mean(cv.cross_val_score(clf, X.toarray(), Y, scoring=tree_cost))

# TODO:
# Add random forest
# Lookup if we can take a model trained on a subset of the data, and elegantly combine it to be as if we used weights

# %% [markdown]
# Run Code for Naive Bayes Classifier

# %%
x, y, xtrain, ytrain, xtest, ytest = prelim_split(test_projects, 'text')
best_params, score = random_optimization(nb_classifier, {'alpha': 300, 'min_df': .05}, {'alpha': 150, 'min_df': .02}, xtrain, ytrain)
vectorizer = CountVectorizer(min_df = best_params['min_df'])
clf        = MultinomialNB(  alpha  = best_params['alpha'])
train_score_display(vectorizer, clf, x, xtrain, ytrain, xtest, ytest)
# Out:
# 1 {'alpha': 233.31769849809544, 'min_df': 0.05} -2517.55982602 {'alpha': 150, 'min_df': 0.02}
# 11
#  {'alpha': 2.6047078607256253, 'min_df': 0.05483401615560048} -2472.20746658 {'alpha': 79.71615000000001, 'min_df': 0.010628820000000004}
# 21
#  {'alpha': 2.6047078607256253, 'min_df': 0.05483401615560048} -2472.20746658 {'alpha': 27.79530283277763, 'min_df': 0.003706040377703685}
# 31
#  {'alpha': 6.265708547780488, 'min_df': 0.05483401615560048} -2471.9710929 {'alpha': 10.768469815377797, 'min_df': 0.0014357959753837064}
# 41
#  {'alpha': 7.6532374993037005, 'min_df': 0.05498368785122476} -2471.96661009 {'alpha': 4.1719258416554075, 'min_df': 0.0005562567788873877}
# 51
#  {'alpha': 7.008683195179412, 'min_df': 0.05498368785122476} -2471.9645393 {'alpha': 1.7958772773843055, 'min_df': 0.00023945030365124078}
# 61
#  {'alpha': 7.197809031314251, 'min_df': 0.05518902084449808} -2471.96437341 {'alpha': 0.6957596529882164, 'min_df': 9.276795373176223e-05}
# 71
# ...

# %% [markdown]
# Run Code for Support Vector Classifier
#  - Model Unsussecful

# %%
vectorizer = CountVectorizer(min_df = best_params['min_df'])
clf = sksvm.SVC(probability=True)

vectorizer.fit(x)
xtrain_v = vectorizer.transform(xtrain)
xtest_v = vectorizer.transform(xtest)
    
clf.fit(xtrain_v, ytrain)
    
score = clf.score(xtest_v, ytest)
calibration_plot(clf, xtest_v, ytest)

# %% [markdown]
# Run Code for Logistic Regression

# %%
best_params, score = random_optimization(log_classifier, {'min_df': .05, 'C':1}, {'min_df': .02, 'C':.5}, xtrain, ytrain)
all_data_vectorizer = CountVectorizer(min_df = best_params['min_df'])
all_data_clf = sklm.LogisticRegression(C = best_params['C'])
all_vec, all_clf = train_score_display(all_data_vectorizer, all_data_clf, x, xtrain, ytrain, xtest, ytest)
# Out:
# 1 {'C': 1, 'min_df': 0.05} -2432.01642768 {'C': 0.45, 'min_df': 0.018000000000000002}
# 11
#  {'C': 0.593873316491236, 'min_df': 0.033387716882561626} -2418.90118759 {'C': 0.19371024450000007, 'min_df': 0.007748409780000004}
# 21
#  {'C': 0.8360660523394027, 'min_df': 0.027999593783495473} -2403.33718944 {'C': 0.11438396227480506, 'min_df': 0.004575358490992203}
# 31
#  {'C': 0.9073020920467226, 'min_df': 0.01769414199112292} -2397.27431332 {'C': 0.0492385451091806, 'min_df': 0.0019695418043672243}
# 41
#  {'C': 0.9073020920467226, 'min_df': 0.018637994403396183} -2397.20023867 {'C': 0.01907602122384731, 'min_df': 0.0007630408489538925}

# %% [markdown]
# We see that our Logistic Classifier is pretty well calibrated up until 80% success. However, since it's given the category data, it seems possible that it might just be implicitly splitting things up by category, taking the success rates of each given category, and then using the success rates of each category to make good predictions. Is the rest of the text data improving the results substantially, or should we just make a simple model splitting things up by category explicitly?
#
# We can test this by running a classifier trained only on data from within one category, and seeing if that provides any predictive value, or if it's just noise. If the classifier trained only from one category works well, then we know that logistic regression is able to make predictions for reasons other than guessing the category. We'll use the Documentary category to explore this, since it has a lot of data, and we want to test the effect of different categories, rather than just the effects of having more or less data.
#
# Further, we can find out whether the classification within a particular category is improved by using information from other categories by running the same test data in both classifiers.

# %%
x, y, xtrain, ytrain, xtest, ytest = prelim_split(test_projects[test_projects['category'] == 'Documentary'], 'text')
best_params, score = random_optimization(log_classifier, {'min_df': .05, 'C':1}, {'min_df': .02, 'C':.5}, xtrain, ytrain)
one_cat_vectorizer = CountVectorizer(min_df = best_params['min_df'])
one_cat_clf = sklm.LogisticRegression(C = best_params['C'])
cat_vec, cat_clf = train_score_display(one_cat_vectorizer, one_cat_clf, all_text_x, xtrain, ytrain, xtest, ytest)

# %%
def best_worst_words(clf, vec):
    words = vec.get_feature_names()

    df = pd.DataFrame({"word": words, "PSuccess": [clf.predict_proba(np.eye(1, len(words), i, dtype=int))[0][1] for i in range(len(words))]})
    df = df.sort(columns='PSuccess', ascending=False)
    
    print "Best Words"
    for i in range(20):
        print df.irow(i).values[1], 'has a predicted' , df.irow(i).values[0], "% chance of success"
        
    df = df.sort(columns='PSuccess')  
    print "\nWorst Words"
    for i in range(20):
       print df.irow(i).values[1], 'has a predicted' , df.irow(i).values[0], "% chance of success"
        
def worst_predictions(clf, vec, xdata, ydata):
    X, Y = make_xy(xdata, ydata, vectorizer=vec)
    
    df = pd.DataFrame({"score": [log_likelihood(clf, [x], [y]) for x, y in zip(X, Y)],
                       "blurb": xdata,
                       "prob": [x[1] for x in clf.predict_proba(X)],
                       "success": ydata
                       }
                      )
    df = df.sort(columns="score")
    
    print "Worst Predictions"
    for i in range(20):
        row = df.irow(i)
        print row['blurb'], ":\t", row['prob'], "%,\t", row['score']
        
def fit_nb(params, x, xtrain, ytrain):
    
    vec = CountVectorizer(min_df = params['min_df'])
    clf = MultinomialNB(alpha = params['alpha'])
    
    vec.fit(x)
    xtrain_v = vec.transform(xtrain)
    xtest_v = vec.transform(xtest)
    
    clf.fit(xtrain_v, ytrain)
    return {'vec': vec, 'clf': clf}

def score_nb(model_dict, xtest, ytest):
    return model_dict['clf'].score(model_dict['vec'].transform(xtest), ytest)

# %%
x, y, xtrain, ytrain, xtest, ytest, train_index, test_index = prelim_split(subdf, 'blurb')
best_params = {}
score = {}
test_data = {}
best_params['all'], score['all'] = random_optimization(nb_classifier, {'min_df': .05, 'alpha':300}, {'min_df': .02, 'alpha':150}, xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-052a3c68d5a1> in <module>()
# ----> 1 x, y, xtrain, ytrain, xtest, ytest, train_index, test_index = prelim_split(subdf, 'blurb')
#       2 best_params = {}
#       3 score = {}
#       4 test_data = {}
#       5 best_params['all'], score['all'] = random_optimization(nb_classifier, {'min_df': .05, 'alpha':300}, {'min_df': .02, 'alpha':150}, xtrain, ytrain)
#
# NameError: name 'prelim_split' is not defined

# %%
categories = subdf.groupby('category').indices.keys()
for c in categories:
    ntrain = subdf[train_index][subdf['category'] == c]
    ntest = subdf[test_index][subdf['category'] == c]
    nxtrain = ntrain['blurb']
    nytrain = ntrain['success']
    nxtest = ntest['blurb']
    nytest = ntest['success']
    
    test_data[c] = [nxtest, nytest]
    best_params[c], score[c] = random_optimization(nb_classifier, {'min_df': .05, 'alpha':300}, {'min_df': .02, 'alpha':150}, nxtrain, nytrain)

# %%
models = {}
score_diff = {}

models['all']= fit_nb(best_params['all'], x, xtrain, ytrain)

for c in categories:
    ntrain = subdf[train_index][subdf['category'] == c]
    ntest = subdf[test_index][subdf['category'] == c]
    nxtrain = ntrain['blurb']
    nytrain = ntrain['success']
    nxtest = ntest['blurb']
    nytest = ntest['success']
    
    vec = CountVectorizer(min_df = best_params['all']['min_df'])
    clf = MultinomialNB(alpha = best_params['all']['alpha'])
    
    models[c] = fit_nb(best_params[c], x, nxtrain, nytrain)
    
    score_diff[c] = score_nb(models[c], nxtest, nytest)

# %%
import operator
sorted_diff = sorted(score_diff.iteritems(), key=operator.itemgetter(1))
print sorted_diff

# %%
for c in ['Metal', 'Fiction', 'Video Games', 'Open Software']:
    print c.upper()
    vec = models[c]['vec']
    clf = models[c]['clf']
    best_worst_words(clf, vec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-92989fd78c8a> in <module>()
#       1 for c in ['Metal', 'Fiction', 'Video Games', 'Open Software']:
#       2     print c.upper()
# ----> 3     vec = models[c]['vec']
#       4     clf = models[c]['clf']
#       5     best_worst_words(clf, vec)
#
# NameError: name 'models' is not defined
# METAL

# %%
from scipy.stats.stats import pearsonr
def pearson_sim(words1, words2):
    diff1=words1['p']#-words['cat_avg']
    diff2=words1['p']#-words['cat_avg']
    rho=pearsonr(diff1, diff2)[0]
    return rho

word_dfs = {}
for c in categories:
    words = vec.get_feature_names()
    word_dfs[c] = pd.DataFrame({"word": words, "p": [clf.predict_proba(np.eye(1, len(words), i, dtype=int))[0][1] for i in range(len(words))]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-edc6678f1a4d> in <module>()
#       7
#       8 word_dfs = {}
# ----> 9 for c in categories:
#      10     words = vec.get_feature_names()
#      11     word_dfs[c] = pd.DataFrame({"word": words, "p": [clf.predict_proba(np.eye(1, len(words), i, dtype=int))[0][1] for i in range(len(words))]})
#
# NameError: name 'categories' is not defined

# %%
import networkx as nx
G = nx.Graph()
for c in categories:
    if not G.has_node(c):
        G.add_node(c)
    for d in categories:
        if not G.has_node(d):
            G.add_node(d)
        G.add_edge(c, d, weight=float(pearson_sim(word_dfs[c], word_dfs[d])))
nx.write_gexf(G, 'categories.gxf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-219646966b5b> in <module>()
#       1 import networkx as nx
#       2 G = nx.Graph()
# ----> 3 for c in categories:
#       4     if not G.has_node(c):
#       5         G.add_node(c)
#
# NameError: name 'categories' is not defined

# %% [markdown]
# # Section 2 - Exploratory Analysis

# %% [markdown]
# ## 2.1 - Effect of project length, and start and end dates

# %% [markdown]
# Came across some suggestive plots here: http://www.kickstarter.com/blog/shortening-the-maximum-project-length

# %%
all_projects = pd.read_csv('all_project_data_time.csv')

# %%
#function to plot how the projects break down by start or end date:
def distr_of_dates(df, time_field):
    data = []
    for time in df[time_field]:
        time = dateutil.parser.parse(time)
        data.append( time.year + time.month / 12. + time.day / 365. )
    plt.hist(data, bins = 20)
    remove_border()
    plt.show()
    
#functions to plot how the projects break down by launch date to deadline:
def distr_of_length(df):
    data = []
    for i, time in enumerate(df['launched_at']):
        time_change = dateutil.parser.parse(df['deadline'][i]) - dateutil.parser.parse(time)
        data.append( time_change.days )
    plt.hist(data, bins = 20)
    remove_border()
    plt.show()
    
#function to plot project success by launch date:
def success_by_dates(df, time_field):
    
    day_dict = {}
    
    for i, time in enumerate(df[time_field]):
        
        time = dateutil.parser.parse(time)
        date = time.year + time.month / 12. + time.day / 365.
        if date not in day_dict.keys():
            day_dict[date] = {'total': 0., 'successful': 0.}
        
        if df['state'][i] == 'successful':
            day_dict[date]['successful'] += 1.
        day_dict[date]['total'] += 1.
            
    dates = day_dict.keys()
    data = [ day_dict[date]['successful'] / ( day_dict[date]['total'] ) for date in dates ]
    plt.plot(dates, data, ',')
    remove_border()
    plt.show()
    
#functions to plot how the projects break down by launch date to deadline:
def success_by_length(df):
   
    length_dict = {}
    
    for i, time in enumerate(df['launched_at']):
        
        time_change = (dateutil.parser.parse(df['deadline'][i]) - dateutil.parser.parse(time)).days
        if time_change not in length_dict.keys():
            length_dict[time_change] = {'total': 0., 'successful': 0.}
        
        if df['state'][i] == 'successful':
            length_dict[time_change]['successful'] += 1.
        length_dict[time_change]['total'] += 1.
            
    lengths = length_dict.keys()
    data = [ length_dict[length]['successful'] / ( length_dict[length]['total'] ) for length in lengths ]
    plt.plot(lengths, data, ',')
    remove_border()
    plt.show()

# %%
print "Success by Project Launch Date"
success_by_dates(all_projects, 'launched_at')

print "Distribution of Project Launch Dates"
distr_of_dates(all_projects, 'launched_at')

print
print "Success by Project Length"
success_by_length(all_projects)

print "Distribution of Project Lengths"
distr_of_length(all_projects)
# Out:
# Success by Project Launch Date
# Distribution of Project Launch Dates
# Success by Project Length
# Distribution of Project Lengths

# %% [markdown]
# Conclusions:
#
# (1) Funding likelihood has been close to constant over time, hovering around 45%.
#
# (2) Shorter projects have succeeded significantly more than have longer projects. This is something we'll want to build into the model.

# %% [markdown]
# ## 2.2 - How much does the "goal" price matter?

# %%
all_projects = pd.read_csv('all_project_data_time.csv')

# %% [markdown]
# How many of these projects are in US dollars?

# %%
print all_projects['currency'].unique()
print len(all_projects[all_projects['currency'] == 'USD'])
# Out:
# ['USD' 'CAD' 'GBP' 'NZD' 'AUD']
# 113962

# %%
us_projects = all_projects.copy()
us_projects = us_projects[us_projects['currency'] == 'USD']

# %% [markdown]
# Most of them are in 'USD' so for now we'll just look at those and ignore exchange rates.
#
# Later, when we do more than just exploratory analysis, we'll look at real exchange rates over time.

# %%
# function to plot distribution of goals:
def distr_of_goals(df):
    plt.hist(df['goal'], bins = [10**(n / 2. + 1) for n in xrange(12)])
    plt.title('Distribution of USD goals')
    plt.xlabel('goal')
    plt.semilogx()
    remove_border()
    plt.show()

  # function to plot absolute money raised as a function of fundraising goal
def dollars_by_goal(input_df):
    df = input_df[input_df['state'] != 'live']
            
    plt.plot(df['goal'], df['pledged'], ',', alpha = .04)
    plt.loglog()
    plt.title('Money raised by goal')
    plt.xlabel('goal')
    plt.ylabel('amount raised')
    remove_border()
    plt.show()
      
  # function to plot absolute money raised as a function of fundraising goal
def fraction_by_goal(input_df):
    df = input_df[input_df['state'] != 'live']
      
    plt.plot(df['goal'], df['pledged'] / df['goal'], ',', alpha = .04)
    plt.loglog()
    plt.xlabel('goal')
    plt.ylabel('fraction raised')
    plt.title('Fraction of goal raised by goal')
    remove_border()
    plt.show()
      
  # function to plot fraction of fundraisers in each range that succeeded\n",
def success_by_goal(input_df):
      
    df = input_df[input_df['state'] != 'live'].reset_index()
    goal_dict = {}
      
    for i, real_goal in enumerate(df['goal']):
         
        goals = [10**(n / 2. + 1) for n in xrange(12)]
        goal = 0
        for n in goals:
            if real_goal > n:
                goal = n
             
        if goal not in goal_dict.keys():
            goal_dict[goal] = {'successful': 0., 'total': 0.}
              
        if df['state'][i] == 'successful':
            goal_dict[goal]['successful'] += 1.
        goal_dict[goal]['total'] += 1
          
    goals = goal_dict.keys()
    data = [goal_dict[goal]['successful'] / goal_dict[goal]['total'] for goal in goals]
      
    plt.plot(goals, data, 'ro')
    plt.semilogx()
    plt.xlabel('goal')
    plt.ylabel('fraction succeeding')
    plt.title('Fraction succeeding by goal')
    remove_border()
    plt.show()

# %%
dollars_by_goal(us_projects)
fraction_by_goal(us_projects)
success_by_goal(us_projects)
distr_of_goals(us_projects)

# %% [markdown]
# Great - so amount asked is a super important parameter for predicting success! We will definitely get this in the model
#
# A note - if the slope of the chance of success vs goal curve is steep enough downward, then maybe people should try kickstarting multiple projects for what is really one goal - so that they get the total amount they need in a few different pieces. (This would be totally dishonest, but an interesting idea)

# %% [markdown]
# ## 2.3 - How much do certain features of the title and blurb matter?

# %%
all_projects = pd.read_csv('all_project_data_time.csv')

# %%
# function to plot distribution of goals:
def distr_of_lengths(df, field):
    data = [len(str(text)) for text in df[field]]
    
    plt.hist(data, bins=20)
    plt.title('Distribution of ' + field + ' length')
    plt.xlabel('character count')
    remove_border()
    plt.show()
    
# function to plot distribution of goals:
def distr_of_caps(df, field):
    data = [np.mean([x.isupper() for x in str(text)]) for text in df[field]]
    
    plt.hist(data, bins=20)
    plt.title('Distribution of percent capital letters in' + field )
    plt.xlabel('percent caps')
    plt.semilogy()
    remove_border()
    plt.show()
    
# function to plot distribution of goals:
def distr_of_word_lengths(df, field):
    data = [np.mean([len(word) for word in str(text).split(' ')]) for text in df[field]]
    
    plt.hist(data, bins=40)
    plt.title('Distribution of average word lengths in' + field )
    plt.xlabel('average word length')
    plt.semilogy()
    remove_border()
    plt.show()

# function to plot success vs percent caps of a text field
def success_by_caps(input_df, field):
    
    df = input_df[input_df['state'] != 'live'].reset_index()
    caps_dict = {}
    
    for i, text in enumerate(df[field]):
        caps = round(np.mean([x.isupper() for x in str(text)]),2)
        
        if caps not in caps_dict.keys():
            caps_dict[caps] = {'successful': 0., 'total': 0.}
                                 
        if df['state'][i] == 'successful':
            caps_dict[caps]['successful'] += 1.
        caps_dict[caps]['total'] += 1.
        
    options = caps_dict.keys()
    data = [caps_dict[caps]['successful'] / caps_dict[caps]['total'] for caps in options]
                
    plt.plot(options, data, 'ro')
    plt.xlabel('fraction capitalized in' + field)
    plt.ylabel('fraction successful')
    plt.title('Success by fraction capitalized in ' + field)
    remove_border()
    plt.show()
    
# function to plot success vs avg word length of a text field
def success_by_avglength(input_df, field):
    
    df = input_df[input_df['state'] != 'live'].reset_index()
    caps_dict = {}
    
    for i, text in enumerate(df[field]):
        caps = np.mean([len(word) for word in str(text).split(' ')])
        caps = round(caps,0)
        
        if caps not in caps_dict.keys():
            caps_dict[caps] = {'successful': 0., 'total': 0.}
                                 
        if df['state'][i] == 'successful':
            caps_dict[caps]['successful'] += 1.
        caps_dict[caps]['total'] += 1.
        
    options = caps_dict.keys()
    data = [caps_dict[caps]['successful'] / caps_dict[caps]['total'] for caps in options]
                
    plt.plot(options, data, 'ro')
    plt.xlabel('avg word length' + field)
    plt.ylabel('fraction successful')
    plt.title('Success by fraction avg word length in ' + field)
    remove_border()
    plt.show()
    
    
# function to plot success vs length of a field
def success_by_length(input_df, field):
    
    df = input_df[input_df['state'] != 'live'].reset_index()
    length_dict = {}
    
    for i, text in enumerate(df[field]):
        length = len(str(text))
        length = length - ( length % 5 )
        
        if length not in length_dict.keys():
            length_dict[length] = {'successful': 0., 'total': 0.}
                                 
        if df['state'][i] == 'successful':
            length_dict[length]['successful'] += 1.
        length_dict[length]['total'] += 1.
        
    lengths = length_dict.keys()
    data = [length_dict[length]['successful'] / length_dict[length]['total'] for length in lengths]
                
    plt.plot(lengths, data, 'ro')
    plt.xlabel('length of ' + field)
    plt.ylabel('fraction successful')
    plt.title('Sucess by length of ' + field)
    remove_border()
    plt.show()

# %%
success_by_caps(all_projects, 'project_name')
distr_of_caps(all_projects, 'project_name')

success_by_caps(all_projects, 'blurb')
distr_of_caps(all_projects, 'blurb')

# %% [markdown]
# This is probably not worth pursuing, since most of the names fall in almost the exact same region in terms of percent caps, so whatever effect we would find would only apply to a very few projects.
#
# Actually though, this might be related to average word length in a project description. Let's take a look at that.

# %%
success_by_avglength(all_projects, 'project_name')
distr_of_word_lengths(all_projects, 'project_name')

success_by_avglength(all_projects, 'blurb')
distr_of_word_lengths(all_projects, 'blurb')

# %% [markdown]
# There's definitely no noticable trend in the blurb word length, and the blurbs all sort of have the same word length anyways.
#
# The strength of the trend in the project names is similar to what we saw with capitalization, though it's not obvious that they have the same trends. There seems to be a trend there, but it's pretty weak, so I'm not sure whether or not we'll end up putting it into the model.

# %% [markdown]
# Now take a look at the length of the titles and blurbs

# %%
success_by_length(all_projects, 'project_name')
distr_of_lengths(all_projects, 'project_name')

success_by_length(all_projects, 'blurb')
distr_of_lengths(all_projects, 'blurb')

# %% [markdown]
# Of course, we can ignore the mess that happens at the really big lengths, since there are very few data points for these.
#
# We see a weak but present trend with project name length. Probably worth looking into.
#
# There might be a significant trend in the blurb lengths. It looks like there is some sort of parabolic shape for blurb lenths < 150 chars. However there aren't very many projects under ~75 words, so we probably won't be able to use the whole curve we seem to be seeing. Still it looks like we might be able to deduce a significant effect of having a ~100 word blurb over a ~150 word blurb.

# %% [markdown]
# ## 2.4 Does location matter?

# %%
all_projects = pd.read_csv('all_project_data_time.csv')
us_projects = all_projects.copy()
us_projects = us_projects[us_projects['currency'] == 'USD']

# %%
def success_by_country(df):
    country_data={}
    
    #iterate through dataframe,creating dictionary entry for each unique country
    for i, country in enumerate(df['country']):
        
        #track success and total for each country
        if country not in country_data.keys():
            country_data[country]={'total':0.,'successful':0.}
            
        if df['state'][i] == 'successful':
            country_data[country]['successful'] += 1.
        country_data[country]['total'] += 1.
    
    #create list of country names, calculate success percentage by country
    labels=country_data.keys()
    data=[ country_data[place]['successful'] / (country_data[place]['total']) for place in labels ]
    print country_data
   
    #print the percentage of success for each country
    for i in range(len(labels)):
        print labels[i],':',data[i]
        
    #plot the data with labels
    x=np.arange(len(labels))
    plt.bar(x,data,align='center', width=.8)
    ticks=plt.xticks(x,labels)
    remove_border()
    plt.ylabel('Percent Successful')
    plt.show()

# %%
print 'Percent of projects successful by country affiliation:'
success_by_country(all_projects)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d858b63cbe58> in <module>()
#       1 print 'Percent of projects successful by country affiliation:'
# ----> 2 success_by_country(all_projects)
#
# NameError: name 'all_projects' is not defined
# Percent of projects successful by country affiliation:

# %%
def success_by_location(df):
    
    location_data={}
    
    #iterate through dataframe,creating dictionary entry for each unique location
    for i, location in enumerate(df['location_name']):
    
        #track success and total for each location
        if location not in location_data.keys():
            location_data[location]={'total':0.,'successful':0.}
            
        if df['state'][i] == 'successful':
            location_data[location]['successful'] += 1.
        location_data[location]['total'] += 1.
    
    #create list of country names, calculate success percentage by state
    labels=location_data.keys()
    print len(labels)
    data=[ location_data[place]['successful'] / (location_data[place]['total']) for place in labels ]
    
    #print the percentage of success for each state
    #for i in range(len(labels)):
        #print labels[i],':',data[i]

    #plot the data with labels
    x=np.arange(len(labels))
    plt.bar(x,data,align='center', width=.8)
    ticks=plt.xticks(x,labels)
    remove_border()
    plt.ylabel('Percent Successful')
    plt.show()

# %%
success_by_location(all_projects)

# %%
states_abbrev = ['AK','AL','AR','AZ','CA','CO','CT','DC','DE','FL','GA','HI',
        'IA','ID','IL','IN','KS','KY','LA','MA','MD','ME','MI','MN','MO','MS',
        'MT','NC','ND','NE','NH','NJ','NM','NV', 'NY','OH','OK','OR',
        'PA', 'RI','SC','SD','TN','TX','UT','VA','VT','WA','WI','WV','WY']
finished_us_projects=us_projects[us_projects['state']!='live']
print 'Number of locations with more than one project',len(finished_us_projects[finished_us_projects['location_name'].duplicated()==True])
print 'Total number of locations',len(finished_us_projects)

# %%
def success_by_state(df):
    from operator import itemgetter
    state_data={}
    
    #iterate through dataframe,creating dictionary entry for each unique state
    for i, location in enumerate(df['location_name']):
        try:
            state_name=location.split(',')[-1].split()[-1]
            if state_name not in state_data.keys() and location.split(',')[-1].split()[-1] in set(states_abbrev):        
                #track success and total for each state
                state_data[state_name]={'total':0.,'successful':0.}
            if df['state'].iloc[i] == 'successful':
                state_data[state_name]['successful'] += 1.
            state_data[state_name]['total'] += 1.
        except:KeyError
            
    
    #create list of country names, calculate success percentage by state
    labels=state_data.keys()
    data=[ state_data[place]['successful'] / (state_data[place]['total']) for place in labels ]
    
    #keep track of the total number of projects actually in the us
    totals=0
    for place in labels:
        totals=state_data[place]['total']+totals
    print 'There are %s projects in the US'%totals
    
    #print the percentage of success for each state
    #sort percentegas,maintain labels
    tuples=[(labels[i],data[i]) for i in range(len(data))]
    tuples=sorted(tuples,key=itemgetter(1))
    
    #extract ordered information and labels
    name=[]
    info=[]
    for i in range(len(tuples)):
        current_name,current_info=tuples[i]
        name.append(current_name)
        info.append(current_info)
        
    #plot the data with labels
    x=np.arange(len(labels))
    plt.figure(figsize=(15, 4))
    plt.bar(x,info,align='center', width=.4)
    ticks=plt.xticks(x,name,rotation='vertical')
    remove_border()
    plt.ylabel('Percent Successful')
    plt.show()

# %%
print 'Success by U.S state'
success_by_state(finished_us_projects)

# %%
#mapping between states and abbreviations,functions for visualization of maps adapted from HW2

states_match = {'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

#adapted from  https://github.com/dataiap/dataiap/blob/master/resources/util/map_util.py
from collections import defaultdict
from matplotlib import colors
import matplotlib.cm as cm
#load in state geometry
state2poly = defaultdict(list)

data = json.load(file("us-states.json"))
for f in data['features']:
    geo = f['geometry']
    if geo['type'] == 'Polygon':
        for coords in geo['coordinates']:
            state2poly[state].append(coords)
    elif geo['type'] == 'MultiPolygon':
        for polygon in geo['coordinates']:
            state2poly[state].extend(polygon)

            
def draw_state(plot, stateid, **kwargs):
    """
    draw_state(plot, stateid, color=..., **kwargs)
    
    Automatically draws a filled shape representing the state in
    subplot.
    The color keyword argument specifies the fill color.  It accepts keyword
    arguments that plot() accepts
    """
    for polygon in state2poly[stateid]:
        xs, ys = zip(*polygon)
        plot.fill(xs, ys, **kwargs)

def make_map(states, label):
    """
    Draw a cloropleth map, that maps data onto the United States
    
    Inputs
    -------
    states : Column of a DataFrame
        The value for each state, to display on a map
    label : str
        Label of the color bar

    Returns
    --------
    The map
    """
    from matplotlib import colors,colorbar
    import matplotlib.cm as cm
    fig = plt.figure(figsize=(12, 9))
    ax = plt.gca()

   #colormap for probabilities 
    cmap = cm.Blues
    vmin, vmax = 0, 1
    
    norm = colors.Normalize(vmin=vmin, vmax=vmax)
    
    for i,state in enumerate(states['Success_Percentage']):
        coloring = cmap(norm(state))
        print coloring
        draw_state(ax, states_match[states.iloc[i].name],color=coloring, ec='k')

    #add an inset colorbar
    ax1 = fig.add_axes([0.45, 0.70, 0.4, 0.02])    
    cb1=colorbar.ColorbarBase(ax1, cmap=cmap,
                                  norm=norm,
                                  orientation='horizontal')
    ax1.set_title(label)
    remove_border(ax, left=False, bottom=False)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlim(-180, -60)
    ax.set_ylim(15, 75)
    return ax

# %%
def success_map(df):
    from operator import itemgetter
    state_data={}
    
    #iterate through dataframe,creating dictionary entry for each unique state
    for i, location in enumerate(df['location_name']):
        try:
            state_name=location.split(',')[-1].split()[-1]
            if state_name not in state_data.keys() and location.split(',')[-1].split()[-1] in set(states_abbrev):        
                #track success and total for each state
                state_data[state_name]={'total':0.,'successful':0.}
            if df['state'].iloc[i] == 'successful':
                state_data[state_name]['successful'] += 1.
            state_data[state_name]['total'] += 1.
        except:KeyError
            
    
    #create list of country names, calculate success percentage by state
    labels=state_data.keys()
    data=[ state_data[place]['successful'] / (state_data[place]['total']) for place in labels ]
   
    #print the percentage of success for each state
    #sort percentegas,maintain labels
    tuples=[(labels[i],data[i]) for i in range(len(data))]
    tuples=sorted(tuples,key=itemgetter(0))
    
    #extract ordered information and labels
    name=[]
    info=[]
    for i in range(len(tuples)):
        current_name,current_info=tuples[i]
        name.append(current_name)
        info.append(current_info)
    state_df=pd.DataFrame(data=info,index=name,columns=['Success_Percentage'])
    return state_df

# %%
#map success percentage of states
state_df=success_map(finished_us_projects)
make_map(state_df,'Success Percentage by State')

# %% [markdown]
# ## 2.5 Check Correlation of Datapoints

# %%
all_projects = pd.read_csv('final_project_data.csv',index_col=0)
all_projects = all_projects[all_projects.state != 'live']
all_projects = all_projects[all_projects.state != 'canceled']
all_projects.index = range(len(all_projects))

# %%
def create_numerical_project_df(df):
    numeric_df = pd.DataFrame({'blank' : df['creator_id'].map(lambda x: 0)})
    numeric_df['title_length'] = [float(len(str(name))) for name in df['project_name']]
    numeric_df['blurb_length'] = [float(len(str(blurb))) for blurb in df['blurb']]
    numeric_df['avg_title-word_length'] = [np.mean([float(len(word)) for word in str(title).split(' ')]) for title in df['project_name']]
    numeric_df['percent_caps_in_title'] = [np.mean([x.isupper() for x in str(text)]) for text in df['project_name']]
    numeric_df['percent_caps_in_blurb'] = [np.mean([x.isupper() for x in str(text)]) for text in df['blurb']]
    groupings = ['category','country','location_name','currency']
    for group in groupings:
        group_list = []
        for i in xrange(len(df)):
            item = str(df[group][i]).replace(" ","")
            group_list.append(item)
        my_dict = dict((field, []) for field in group_list)
        for i, key in enumerate(my_dict.keys()):
            my_dict[key].append(i)
        for i in xrange(len(group_list)):
            group_list[i] = my_dict[group_list[i]][0]
        numeric_df[group] = group_list
    numeric_df = numeric_df.drop('blank',1)
    numeric_df['goal_dollars'] = df.goal_dollars
    numeric_df['project_length'] = df.project_length
    numeric_df['goal'] = df.goal
 
        
    return numeric_df

# %%
numeric_df = create_numerical_project_df(all_projects)

# %%
def corr_numericals(project_df):
    project_df = project_df.copy()
    numeric_fields = ['title_length', 'blurb_length', 'avg_title-word_length', 'percent_caps_in_title', 'percent_caps_in_blurb', 'category', 'country', 'location_name', 'currency', 'goal_dollars', 'project_length', 'goal']
    for col1,col2 in itertools.combinations(numeric_fields,2):
        print col1,col2, np.corrcoef(project_df[col1],project_df[col2])[0][1]
        if abs(np.corrcoef(project_df[col1],project_df[col2])[0][1])>=0.1:
            print ''

# %%
corr_numericals(numeric_df)
# Out:
# title_length blurb_length 0.173267629201
#
# title_length avg_title-word_length -0.0498345927638
# title_length percent_caps_in_title -0.232579890782
#
# title_length percent_caps_in_blurb 0.0281872268842
# title_length category -0.0119677243031
# title_length country
# 0.00453869840422
# title_length location_name -0.0172797566616
# title_length currency -0.00885930731009
# title_length goal_dollars -0.00276275170989
# title_length project_length 0.0403404851939
# title_length goal
# -0.00249033443586
# blurb_length avg_title-word_length -0.00868941224257
# blurb_length percent_caps_in_title -0.0417897487655
# blurb_length percent_caps_in_blurb -0.155871970542
#
# blurb_length category 0.0158053210115
# blurb_length country
# 0.00683990321076
# blurb_length location_name -0.00654020077192
# blurb_length currency -0.00854117466969
# blurb_length goal_dollars -0.00375835008986
# blurb_length project_length 0.0658923972826
# blurb_length goal
# -0.00332334592759
# ...

# %% [markdown]
# ## 2.6 Correlation Plots

# %%
#scatterplots and covariances of different metrics

def scatter_df_columns(df, scatterx, scattery):
    
    figure=plt.figure(figsize=(8,8))
   
    axes=figure.gca()
   
    x=df[scatterx]
    y=df[scattery]
    
    axes.scatter(x, y, cmap=colorscale, c=col)
    axes.set_xlabel(scatterx);
    axes.set_ylabel(scattery);
    
    return axes

def scatter_cov(scatter1,scatter2,label1='',label2=''):
    plt.figure(figsize=(6, 4))
    plt.subplot(121)
    plt.scatter(scatter1, scatter2,marker='.',alpha=.01)
    plt.xlabel(label1)
    plt.ylabel(label2)
    remove_border()
    
    
    c=np.corrcoef(scatter1,scatter2)
    plt.semilogx()
    
    print 'Correlation of %s and %s is' %(label1,label2),c[0,1]

# %%
goal=all_projects['goal']
time_length=[(dateutil.parser.parse(all_projects['deadline'][i]) - dateutil.parser.parse(time)).days for i, time in enumerate(all_projects['launched_at'])]

# %%
scatter_cov(goal,time_length,"goal","time length of project")
# Out:
# Correlation of goal and time length of project is 0.0291095457704

# %%
dataEZ=[
                    {'name': 'project length', 'values': all_projects['project_length'], 'successes': (all_projects['state'] == 'successful')},
                    {'name': 'goal', 'values': all_projects['goal'], 'successes': (all_projects['state'] == 'successful')},
                    {'name': 'dollar-value goal', 'values': all_projects['goal_dollars'], 'successes': (all_projects['state'] == 'successful')},
                    {'name': 'title length', 'values': [float(len(str(name))) for name in all_projects['project_name']], 'successes': (all_projects['state'] == 'successful')},
                    {'name': 'blurb length', 'values': [float(len(str(blurb))) for blurb in all_projects['blurb']], 'successes': (all_projects['state'] == 'successful')},
                    {'name': 'avg title-word length', 'values': [np.mean([float(len(word)) for word in str(title).split(' ')]) for title in all_projects['project_name']], 'successes': (all_projects['state'] == 'successful')},
                    {'name': 'percent caps in title', 'values': [np.mean([x.isupper() for x in str(text)]) for text in all_projects['project_name']], 'successes': (all_projects['state'] == 'successful')},
                    {'name': 'percent caps in blurb', 'values': [np.mean([x.isupper() for x in str(text)]) for text in all_projects['blurb']], 'successes': (all_projects['state'] == 'successful')},
                    ]

# %%
def get_correlation(data):
    for i in range(len(data)):
        for j in range(len(data)):
            if i<j:
                scatter1=data[i]['values']
                label1=data[i]['name']
                scatter2=data[j]['values']
                label2=data[j]['name']
                scatter_cov(scatter1,scatter2,label1,label2)

# %%
def get_correlation_pretty(data):
    fig,axes=plt.subplots(figsize=(28,20), nrows=4, ncols=7)
    row_counter=0
    col_counter=0
    for i in range(len(data)):
        for j in range(len(data)):
            if i<j:
                #update fields to compare
                scatter1=data[i]['values']
                label1=data[i]['name']
                scatter2=data[j]['values']
                label2=data[j]['name']
                
                #create scatterplot
                axes[row_counter][col_counter].scatter(scatter1, scatter2,marker='.',alpha=.01)
                
                #caculate correlation,set labels
                c=np.corrcoef(scatter1,scatter2)
                axes[row_counter][col_counter].set_title('Correlation:%f'%c[0,1]) 
                axes[row_counter][col_counter].set_xlabel(label1)
                axes[row_counter][col_counter].set_ylabel(label2)
                plt.semilogx()
                remove_border()
                #update counters
                col_counter=(col_counter+1)%7
                if col_counter==0:
                    row_counter+=1

# %%
#call function to get the correlation and scatter plot of every combination of numerical fields
get_correlation_pretty(dataEZ)

# %% [markdown]
# # Section 3 - Making models for various parameters

# %% [markdown]
# # 3.0 - Splitting the Data

# %% [markdown]
# Before we go into building actual models (which we'll be optimizing according to the data), we need to split out stuff into training and test sets. This test set will be the one on which we evaluate how well our model works, but which we don't use to choose what our model is. Within this training set, we'll be resplitting and cross-validating to test the model.
#
# From here on, we'll only be interested in projects that either failed or were successful (the other possibilities are live and cancelled), since the other options don't inform our predictions.

# %%
all_projects = pd.read_csv('final_project_data.csv', index_col=0)
all_projects = all_projects[all_projects['state'] != 'live']
all_projects = all_projects[all_projects['state'] != 'cancelled']
all_projects.index = range(len(all_projects))
len(all_projects.iloc[:,0])
# Out:
# 115463

# %%
def make_text(row, columns):
    text = ''+str(row['blurb'])
    for c in columns:
        ctext = c
        if c == 'category':
            ctext = "l".join(str(row[c]).split(" "))
        text += " " + " ".join([str(ctext) + "X" + str(word) for word in str(row[c]).split(" ")])
    return text

def multiply_by_cat(row, b):
    cat = "l".join(str(row['category']).split(" "))
    return " ".join([cat + "X" + word for word in str(row[b]).split(" ")])

def exclude(df, field, set_avoid):
    ans = [1 for i in range(len(df[field].values))]
    df = df
    for avoid in set_avoid:
        df = df[df[field] != avoid]
    return df

# %% [markdown]
# We'll split into roughly 100,000 and 15,000

# %%
random_indices = (np.random.random(len(all_projects)) < (15000. / len(all_projects)))

sub_df = all_projects.copy()
sub_df['split'] = random_indices

test_projects = sub_df[random_indices == True]
train_projects = sub_df[random_indices == False]

test_projects.index = range(len(test_projects))
train_projects.index = range(len(train_projects))

test_projects['cat_title'] = test_projects.apply(lambda row: multiply_by_cat(row, 'project_name'), axis=1)
test_projects['success'] = test_projects.apply(lambda row: int(row['pledged'] - row['goal'] > 0), axis=1)
test_projects['textalt'] = test_projects.apply(lambda row: make_text(row, ['cat_title', 'category', 'currency']), axis=1)
test_projects['text']    = test_projects.apply(lambda row: make_text(row, ['project_name', 'category', 'currency']), axis=1)

train_projects['cat_title'] = train_projects.apply(lambda row: multiply_by_cat(row, 'project_name'), axis=1)
train_projects['success'] = train_projects.apply(lambda row: int(row['pledged'] - row['goal'] > 0), axis=1)
train_projects['text']    = train_projects.apply(lambda row: make_text(row, ['project_name', 'category', 'currency']), axis=1)
train_projects['textalt'] = train_projects.apply(lambda row: make_text(row, ['cat_title', 'category', 'currency']), axis=1)

#dropping extra field so github doesn't throw a hissy fit
fields = ['creator_joined','backers_count','creator_name', 'creator_slug', 'creator_url','deadline','launched_at','project_url','project_slug','last_state_change','split']
for field in fields:
    test_projects = test_projects.drop(field,1)
    train_projects = train_projects.drop(field,1)



test_projects.to_csv('test_projects.csv')
train_projects.to_csv('train_projects.csv')

# %%
print test_projects.iloc[0,:]
# Out:
# backers_count                                                          185
# blurb                    The Maysles Cinema will bring the sweet sounds...
# category                                                             Music
# country                                                                 US
# creator_id                                                        86975874
# currency                                                               USD
# goal                                                                  5000
# location_id                                                   2.828882e+07
# location_name                                        Harlem, Manhattan, NY
# pledged                                                               8105
# project_id                                                      1249992493
# project_name             The Maysles Cinema's Outdoor Live Music and Fi...
# ...

# %% [markdown]
# ## 3.1 Models for numerical data

# %% [markdown]
# ### 3.1.1 - Framework

# %% [markdown]
# The goal here is to write code that will take in the projects and optimally fit a curve to describe the effect a numerical field - like blurb length, project goal, etc. - has on chance of success.
#
# The input to this code will be a dataframe of projects and a function obtaining some field for each such project.
#
# The output from this code will be a function that takes a project and predicts its success based on the field of interest. The function outputted will minimize something like log-likelihood, or number of correct guesses, etc.
#
# There are many different classifiers (thank you, sklearn) that we could use to make these models. How to choose:
#
# (1) We know from our exploration that some of the curves we're trying to model have strange-looking or jagged-y. This suggests that doing polynomial models might be messy.
#
# (2) None of our numerical fields are significantly correlated (section 2.5, 2.6) so we can model them independently. This means that our data is going to be quite dense - we have many thousand points, and only one curve to infer from it.
#
# Conclusion - kNN approaches should handle the jagged-ness well, since there is no underlying model. And we don't have to worry about them having sparcity problems since we're only working in 1D. So let's try kNN over a bunch of k's. We'll also through in a logistic regression for the heck of it and see it it ever outperforms kNN.
#
# Finally, just an overview of what we'll have our function do here (for each numerical field):
#
# (1) do a recap in graphs of the explanatory section. Note that OUR HISTOGRAMS PLOT WITH POINTS, NOT BARS (since plt.hist has trouble with log scales)
#
# (2) On some random subset of the training data, go through several different classifiers and obtain a score via kfold cross-validation.
#
# (3) Pick the model with the best log-likelihood score, plot what its predictions look like.
#
# (4) Print out how well the model performs on the test data (which we're NOT using to optimize the model), according to log-likelihood and fraction-guessed-correctly (by rounding estimate).
#
# A Final Note:
#
# We're not using true log-likelihood. Rather we've using a version that penalizes impossible guesses as less than infinitely bad. It makes sense to do this - that is, to raise 0 probability guesses to 1/1000 and lower 1 probability guesses to 999/1000 - because we don't intend for our model to be accurate to 0.1% likelihood, so it wouldn't make sense to penalize it for being off this much. Another way of looking at this is that we're changing our classifier to avoid making 0 or 1 guesses.

# %%
#first some functions to give an explanatory recap

#doing this one the hard way since plt histograms are junk with log scales (similar to success_by_field)
def numerical_distr(field_name, values, log_x, log_y):
    num_buckets = 30
    min_value, max_value = min(values), max(values)
    buckets = [0 for i in xrange(num_buckets)]
    
    if log_x:
        bucket_space = np.logspace(np.log(min_value) / np.log(10.), np.log(max_value) / np.log(10.), num_buckets)
    else:
        bucket_space = np.linspace(min_value, max_value, num_buckets)
        
    for i, value in enumerate(values):
        num = 0
        for j, term in enumerate(bucket_space):
            if value < term:
                num = j - 1
                break
        buckets[num] += 1
        
    plt.plot(bucket_space, buckets, 'ro')
    plt.xlabel(field_name)
    if log_x:
        plt.semilogx()
    if log_y:
        plt.semilogy()
    plt.title('Number of projects by ' + field_name)
    remove_border()
    plt.show() 

    
def success_by_field(field_name, values, successes, log_x):
    
    num_buckets = 50
    min_value, max_value = min(values), max(values)
    buckets = [{'successful': 0., 'total': 0.} for i in xrange(num_buckets)]
    
    if log_x:
        bucket_space = np.logspace(np.log(min_value) / np.log(10.), np.log(max_value) / np.log(10.), num_buckets)
    else:
        bucket_space = np.linspace(min_value, max_value, num_buckets)
        
    for i, value in enumerate(values):
        num = 0
        for j, term in enumerate(bucket_space):
            if value < term:
                num = j - 1
                break         
        buckets[num]['successful'] += 1 if successes[i] else 0
        buckets[num]['total'] += 1 
    
    data = [bucket['successful'] / (bucket['total'] + 0.01) for bucket in buckets]
    
    plt.plot(bucket_space, data, 'ro')
    plt.xlabel(field_name)
    plt.ylabel('fraction successful')
    if log_x:
        plt.semilogx()
    plt.title('Success by ' + field_name)
    remove_border()
    plt.show() 

# now we want to fit some curves to our model
# this is our starting cost functions
def log_likelihood(clf, x, y):
    L = 0
    proba = clf.predict(x)
    
    #fudged slightly so that things don't get wrecked by zero-probability events (see explanation in markdown above)
    for i, term in enumerate(proba):
        proba[i] += 1./1000 if term == 0 else 0
        proba[i] -= 1./1000 if term == 1 else 0
        
    true_logs = np.log(proba)
    false_logs = np.log(1 - proba)
    
    for index, value in enumerate(y):
        L += true_logs[index] if value == 1 else false_logs[index]
            
    return L

def fraction_correct(clf, x, y):
    proba = clf.predict(x) 
    guess = np.around(proba)
    return np.mean(guess == y)

def both_metrics(clf, x, y):
    L = 0
    proba = clf.predict(x)
    
    #fudged slightly so that things don't get wrecked by zero-probability events
    for i, term in enumerate(proba):
        proba[i] += 1./1000 if term == 0 else 0
        proba[i] -= 1./1000 if term == 1 else 0
        
    true_logs = np.log(proba)
    false_logs = np.log(1 - proba)
    
    for index, value in enumerate(y):
        L += true_logs[index] if value == 1 else false_logs[index]
    
    guess = np.around(proba)
    fraction_correct = np.mean(guess == y)
    
    return [L, fraction_correct]
        

#this cross validates with diff random subsets of the data
def cv_score(clf, x, y, score_func):
    result = 0
    nfold = 5
    for train, test in KFold(y.size, nfold): # split data into train/test groups, 5 times
        clf.fit(x[train], y[train]) # fit
        result += score_func(clf, x[test], y[test]) # evaluate score function on held-out data
    return result / nfold # average

#for making my own classifiers that fit into this framework:
#Smoothing Classifier works like kNN but if there are points with same x-value, includes all
class SmoothingClassifier():
    def __init__(self, min_group):
        self.x = np.array([])
        self.y = np.array([])
        self.clf = []
        self.min_group = min_group
        
    def fit(self, X, Y):
        clf = KNeighborsRegressor(n_neighbors=self.min_group, weights='uniform')
        clf.warn_on_equidistant = False
        clf.fit(X, Y)
        
        self.clf = clf
        self.x = X
        self.y = Y
        
    def predict(self, X):
        
        count = 0
        
        result = self.clf.predict(X)
        for i, x in enumerate(X):
            matches = np.array(np.where(self.x == x))
            if matches.size > self.min_group:
                count += 1
                result[i] = np.mean(self.y[matches])
        
        print count
        
        return result

#this generates a bunch of different classifiers we'll try:
def generate_classifiers():
    result = []
    
    for k in [3**(n+1) for n in xrange(6)]:      #xrange(8)]: sometimes these are the best models, but they take too long to run
        #Skip now
        #clf = SmoothingClassifier(k)
        #result.append(clf)
        
        clf = KNeighborsRegressor(n_neighbors=k, weights='uniform', algorithm='auto') #uniform since distance -> division by zero
        clf.warn_on_equidistant = False
        result.append(clf)
        
    clf = LogisticRegression(C=1.0, penalty='l1')
    result.append(clf)
    
    return result

# this tests out a bunch of possible classifiers
def optimize_classifier(x, y, to_max):
    best_score, best_clf = - np.inf, []
    
    for clf in generate_classifiers():
        score = cv_score(clf, x, y, to_max)
        
        #print clf
        #print score
        #print
                 
        if score > best_score:
            best_score = score
            clf.fit(x, y)
            best_clf = clf
    
    return best_score, best_clf

# plot a rough outline of the predictions our model makes
def plot_classifier(clf, x, score, field_name, log_x):
    open_x = [term[0] for term in x]
    
    if log_x:
        pre_x_plot = np.logspace(np.log(min(open_x)) / np.log(10.), 
                                 np.log(max(open_x)) / np.log(10.), 
                                 1000)
    else:
        pre_x_plot = np.linspace( min(open_x), max(open_x), 1000)
    x_plot = np.array([[term] for term in pre_x_plot])
    
    predictions = clf.predict(x_plot)
    
    plt.scatter(pre_x_plot, predictions)
    plt.title('prediced project success vs ' + field_name + ' (score: ' + str(score) + ')')
    plt.xlabel(field_name)
    plt.xlim([min(pre_x_plot), max(pre_x_plot)])
    plt.ylim([min(0, min(predictions)), max(1, max(predictions))])

    if log_x:
        plt.semilogx()

    plt.show()

# this is the total thing that we'll run - starting with the training and test values in a field and whether or not
# the corresponding projects succeeded, we print out explanatory graphs and we optimize a classifier 
def numerical_model(train_values, train_successes, test_values, test_successes, name, to_max, training_size, log_x = False, distr_log_y = False):
    
    #format
    train_values, train_successes = np.array(train_values), np.array(train_successes)
    
    #get an appropriately size random subset of the data to train with so code doesn't take forever
    random_indices = (np.random.random(train_successes.size) < (float(training_size) / train_successes.size))
    
    values, successes = np.array([]), np.array([])
    for i, value in enumerate(random_indices):
        if value:
            values = np.append(values, np.array([train_values[i]]))
            successes = np.append(successes, np.array([train_successes[i]]))
    
    #plot the distribution of this field and its successes
    numerical_distr(name, values, log_x, distr_log_y)
    success_by_field(name, values, successes, log_x)
    
    #find the best model and plot the results
    values = np.array([[term] for term in values])
    score, clf = optimize_classifier(values, successes, to_max)
    plot_classifier(clf, values, score, name, log_x)
    print 'best' + str(clf)
    
    metrics = both_metrics(clf, np.array([[term] for term in test_values]), test_successes)
    print 'log_likelihood: ' + str(metrics[0])
    print 'fraction guessed correctly: ' + str(metrics[1])
    
    return clf.predict(np.array([[term] for term in train_values])), clf.predict(np.array([[term] for term in test_values]))

# %% [markdown]
# Let's try this huge code out on some field and see that it works!

# %%
train_projects = pd.read_csv('train_projects.csv', index_col = 0)
test_projects = pd.read_csv('test_projects.csv', index_col = 0)

# %%
train_successes = train_projects['state'] == 'successful'
test_successes = test_projects['state'] == 'successful'

# %%
numerical_model(train_projects['goal'], train_successes, test_projects['goal'], test_successes, 'goal', log_likelihood, 5000, log_x = True, distr_log_y = True)
# Out:
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, n_neighbors=243, p=2,
#           warn_on_equidistant=False, weights=uniform)
# log_likelihood: -65718.6578268
# fraction guessed correctly: 0.609170696758
# (array([ 0.35802469,  0.40329218,  0.43209877, ...,  0.67489712,
#         0.20987654,  0.55555556]),
#  KNeighborsRegressor(algorithm='auto', leaf_size=30, n_neighbors=243, p=2,
#           warn_on_equidistant=False, weights='uniform'))

# %% [markdown]
# Let's also do a trial where we train our model on a bigger subset of the data, to make sure that we aren't doing poorly from having to sparse a dataset. It doesn't really seem like this should be a problem, since the data appears to be well-behaved enough that 5000 points should be enough to describe it.

# %%
numerical_model(train_projects['goal'], train_successes, test_projects['goal'], test_successes, 'goal', log_likelihood, 10000, log_x = True, distr_log_y = True)
# Out:
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, n_neighbors=243, p=2,
#           warn_on_equidistant=False, weights=uniform)
# log_likelihood: -9627.74095163
# fraction guessed correctly: 0.609522515792
# (array([ 0.32510288,  0.35802469,  0.58436214, ...,  0.67078189,
#         0.67078189,  0.14403292]),
#  array([ 0.40740741,  0.16460905,  0.42798354, ...,  0.65432099,
#         0.5473251 ,  0.6090535 ]))

# %% [markdown]
# Ok, great! The 10,000 data-point model is getting comparable scores on the test set (comparable log likelihood, comparable fraction guessed, but all in all nearly the same).
# So we don't have to train our models on 10,000: 5000 is big enough.

# %% [markdown]
# ### 3.1.2 - Application of framework to data

# %% [markdown]
# Our model takes in an array of values, an array of their successes, and a couple of less important things - and returns some graphs and a classifier, as well as some values about how good the fit is.
#
# Here we're going to generate the models for all the numerical fields we have / still think are relevant. We'll print them out one-by-one and save the model's prediction on finished projects to a csv. Later we'll combine these predictions in an optimized way!
#
# Note that we're modelling each field independently. This is because none of them are heavily correclated, except goal and dollar-value goal, but obviously we'll only need one of these (hopefully dollar-value goal).

# %%
# get the training projects and the test projects
train_projects = pd.read_csv('train_projects.csv', index_col = 0)
test_projects = pd.read_csv('test_projects.csv', index_col = 0)

# %%
# this makes a convenient dataframe that contains the numeric fields we've modelled
def make_numeric(df):
    numeric_df = pd.DataFrame({'blank' : df['creator_id'].map(lambda x: 0)})
    numeric_df['title_length'] = [float(len(str(name))) for name in df['project_name']]
    numeric_df['blurb_length'] = [float(len(str(blurb))) for blurb in df['blurb']]
    numeric_df['avg_title_word_length'] = [np.mean([float(len(word)) for word in str(title).split(' ')]) for title in df['project_name']]
    numeric_df['percent_caps_in_title'] = [np.mean([x.isupper() for x in str(text)]) for text in df['project_name']]
    numeric_df['percent_caps_in_blurb'] = [np.mean([x.isupper() for x in str(text)]) for text in df['blurb']]
    numeric_df['goal_dollars'] = df.goal_dollars
    numeric_df['project_length'] = df.project_length
    numeric_df['goal'] = df.goal
    numeric_df['successful'] = [int(item =='successful') for item in df.state]
    numeric_df = numeric_df.drop('blank',1)
    
    return numeric_df

# %%
# get the numeric fields, for the test and the training
train_numeric = make_numeric(train_projects)
test_numeric = make_numeric(test_projects)

# %%
# jsut some info on how to make the plots
def log_values(string):
    return False if 'caps' in string else True

# %%
# function to run the numerical modelling code, printing out graphs and returning predictions
def run_numerical_model(col):
    probs_df_train = pd.read_csv('sub_model_predictions_train.csv',index_col=0)
    probs_df_test = pd.read_csv('sub_model_predictions_test.csv',index_col=0)
    num_train, num_test = numerical_model(
                                      train_numeric[col],
                                      train_numeric['successful'],
                                      test_numeric[col],
                                      test_numeric['successful'],
                                      col,
                                      log_likelihood, 
                                      5000, 
                                      log_x = log_values(col), 
                                      distr_log_y = True)
    probs_df_train[col] = num_train
    probs_df_test[col] = num_test
    probs_df_train.to_csv('sub_model_predictions_train.csv')
    probs_df_test.to_csv('sub_model_predictions_test.csv')

# %%
# set up dataframes to save our predictions into
probs_df_train = pd.DataFrame({'blank' : train_projects['creator_id'].map(lambda x: 0)})
probs_df_train.to_csv('sub_model_predictions_train.csv')
probs_df_test = pd.DataFrame({'blank' : test_projects['creator_id'].map(lambda x: 0)})
probs_df_test.to_csv('sub_model_predictions_test.csv')

# %%
column_names = ['project_length', 'goal', 'goal_dollars','avg_title_word_length',
                     'percent_caps_in_title', 'percent_caps_in_blurb','title_length','blurb_length']

# %%
# actually run the numerical modelling...
for col in column_names:
    run_numerical_model(col)
# Out:
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, metric=minkowski,
#           n_neighbors=81, p=2, weights=uniform)
# log_likelihood: -9933.91455039
# fraction guessed correctly: 0.580927800041
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, metric=minkowski,
#           n_neighbors=243, p=2, weights=uniform)
# log_likelihood: -9642.57096386
# fraction guessed correctly: 0.611424302112
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, metric=minkowski,
#           n_neighbors=243, p=2, weights=uniform)
# log_likelihood: -9644.42203097
# fraction guessed correctly: 0.593221490185
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, metric=minkowski,
#           n_neighbors=729, p=2, weights=uniform)
# log_likelihood: -10112.75512
# fraction guessed correctly: 0.549955851389
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, metric=minkowski,
#           n_neighbors=729, p=2, weights=uniform)
# log_likelihood: -10117.5981033
# ...

# %%
# clean up the dataframes / csvs we saved the predictions into
probs_df_train = pd.read_csv('sub_model_predictions_train.csv',index_col=0)
probs_df_train = probs_df_train.drop('blank', 1)
probs_df_train.to_csv('sub_model_predictions_train.csv')

probs_df_test = pd.read_csv('sub_model_predictions_test.csv',index_col=0)
probs_df_test = probs_df_test.drop('blank', 1)
probs_df_test.to_csv('sub_model_predictions_test.csv')

# %% [markdown]
# ## 3.2 - Models for Categorical Data

# %% [markdown]
# ### 3.2.1 - Framework

# %% [markdown]
# Here we're trying to do exactly what we did in the numerical case, just for categorical rather than numerical data - that is, given a numerical field, we want to print out some recap about its distribution and relationship with success, find the best (according to log-likelihood) model we can for it, and then save the predictions that the model makes on our training set (for the model combination later on).
#
# A very convenient fact: for categorical data, log-likelihood is easy to minimize. Assuming that we have enough data in all categories to outweigh any priors we might have about how they affect success (and we almost always do have enough), then the best prediction is to say that a project with value A in category B will succeed with probability equal to the fraction of projects in the training set that had value A that succeeed. This also maximizes the fraction-guessed metric. So the model-making is very easy!

# %% [markdown]
# Functions to remind ourselves of the bargraphs from above

# %%
# plot a pretty histograph of the distribution of projects according to some categories
def hist_categorical_dist(full_array,title):
    my_dict = defaultdict(int)
    for word in full_array:
        my_dict[word] += 1
    values = []
    labels = []
    sorted_dict = sorted(my_dict.iteritems(), key=operator.itemgetter(1))
    for label,value in sorted_dict:
        labels.append(label)
        values.append(value)
    lefts = []
    locs = []
    colors = []
    for i in xrange (len(labels)):
        lefts.append(i*2+.1)
        locs.append(i*2+1)
        if i%2 == 0:
            colors.append('c')
        else:
            colors.append('b')
    fig = plt.figure()
    fig.set_size_inches(20.,5.)
    y_max = np.max(values)+1000
    plt.bar(left=lefts,height=values,width=1.8,color= colors)  
    plt.xlim(0,2*len(labels))
    plt.ylim(0,y_max)
    plt.xticks(locs,labels,rotation=90,fontsize=8)
    remove_border()
    plt.title(title)
    plt.show()
"""
Function
--------
success_by_category:
    Plots a bar graph of success percent by category

Assumptions
-----------
One or more successes per category

Parameters
-----------
full_array : Numpy ndarray
    ndarray of all data for categories
success_array : Numpy ndarray
    subset of the full array for project categories if the project was successful
title: string
    title of the bargraph to be printed
    
Returns
-------
None

Print Outs:
-----------
Bar graph of percent success by category
"""    

def success_by_category(full_array,success_array,title):
    my_dict_1 = defaultdict(int)
    for word in full_array:
        my_dict_1[word] = 0
    for word in success_array:
        my_dict_1[word] += 1
    my_dict_2 = defaultdict(int)
    for word in full_array:
        my_dict_2[word] += 1    
    values_1 = []
    labels_1 = []
    values_2 = []
    labels_2 = []
    values = []
    labels = []
    tuples = []
    for label,value in my_dict_1.items():
        labels_1.append(label)
        values_1.append(value)
    sorted_dict = sorted(my_dict_2.iteritems(), key=operator.itemgetter(1))
    for label,value in sorted_dict:
        labels_2.append(label)
        values_2.append(value)
    for i in xrange(len(labels_2)):
        for j in xrange(len(labels_1)):
            if labels_2[i] == labels_1[j]:
                my_tup  = (float(values_1[j])/values_2[i],labels_1[j])
                tuples.append(my_tup)
    for i in xrange(len(tuples)):
        values.append(tuples[i][0])
        labels.append(tuples[i][1])
    lefts = []
    locs = []
    colors = []
    for i in xrange (len(labels)):
        lefts.append(i*2+.1)
        locs.append(i*2+1)
        if i%2 == 0:
            colors.append('c')
        else:
            colors.append('b')
    fig = plt.figure()
    fig.set_size_inches(20.,5.)
    plt.bar(left=lefts,height=values,width=1.8,color= colors)  
    plt.xlim(0,2*len(labels))
    plt.ylim(0,1)
    plt.xticks(locs,labels,rotation=90,fontsize=8)
    remove_border()
    plt.title(title)
    plt.show()

# Here we're just writing our own classifier that models categorical data as we discussed earlier
# namely, the probability of success it gives is just the rate of success of things in some category in the fitting set
class Classifier():
    def __init__(self):
        self.proba_dict = {}
        self.average = 0
        
    def fit(self, X, Y):
        grouper = {}
        for i, term in enumerate(X):
            if term not in grouper.keys():
                grouper[term] = {'successful': 0., 'total': 0.}
            if Y[i]:
                grouper[term]['successful'] += 1.
            grouper[term]['total'] += 1.
        
        self.proba_dict = dict((key, float(grouper[key]['successful']) / grouper[key]['total']) for key in grouper.iterkeys())
        self.average = np.mean(Y)
    def predict(self, X):
        
        result = []
        for term in X:
            try:
                result.append(self.proba_dict[term])
            except KeyError:
                result.append(self.average)
        
        return np.array(result)
    
# here are our two metrics for evaluating how good predictions are
def log_likelihood(clf, x, y):
    L = 0

    proba = clf.predict(x)
    #fudged slightly so that things don't get wrecked by zero-probability events
    for i, term in enumerate(proba):
        proba[i] += 1./1000 if term == 0 else 0
        proba[i] -= 1./1000 if term == 1 else 0
    
    for index, value in enumerate(y):
        L += np.log(proba[index]) if value == 1 else np.log(1 - proba[index])
   
    return L 

def fraction_correct(clf, x, y):
    proba = clf.predict(x)
    guess = np.array([round(term, 0) for term in proba])
    return np.mean(guess == y)

# putting it all together
# this function that takes in training and testing data frames and te column we're interested in
# then it outputs some explanatory graphs and the model's predictions
def categorical_model(train_df,test_df,grouping,title):
    if len(set(list(train_df[grouping])))<=100:
        hist_categorical_dist(train_df[grouping],title)
        success_by_category(train_df[grouping],train_df[grouping][train_df.state == 'successful'],title)
    clf = Classifier()
    x_set_train = np.array(train_df[grouping])
    x_set_test = np.array(test_df[grouping])
    y_set_train = np.array([int(term == 'successful') for term in train_df.state])
    y_set_test = np.array([int(term == 'successful') for term in test_df.state])
    clf.fit(x_set_train, y_set_train)
    l = log_likelihood(clf, x_set_test, y_set_test)
    frac_correct = fraction_correct(clf, x_set_test, y_set_test)
    print grouping+' Log Likelihood Score: ' + str(l)
    print grouping+' Fraction Guess Correct: ' + str(frac_correct)
    return clf

# %% [markdown]
# ### 3.2.2  - Application of categorical framework to data3.2.2 Application of Framework

# %%
# get the test and training sets
train_projects = pd.read_csv('train_projects.csv', index_col=0)
test_projects = pd.read_csv('test_projects.csv', index_col=0)

# %%
# run the cateogrical modelling code
groupings = ['category','country','location_name','currency','website_overall']
tuples_list = []
for group in groupings:
    title = group+' Graphs'
    clf = categorical_model(train_projects,test_projects,group,title)
    tuples = (group,clf)
    tuples_list.append(tuples)
# Out:
# category Log Likelihood Score: -9705.10136629
# category Fraction Guess Correct: 0.611899748693
# country Log Likelihood Score: -10096.2915145
# country Fraction Guess Correct: 0.55341981933
# location_name Log Likelihood Score: -11366.9524913
# location_name Fraction Guess Correct: 0.584935135502
# currency Log Likelihood Score: -10096.2915145
# currency Fraction Guess Correct: 0.55341981933
# website_overall Log Likelihood Score: -10069.1672897
# website_overall Fraction Guess Correct: 0.556747945392

# %%
# save the results!
probs_df_train = pd.read_csv('sub_model_predictions_train.csv',index_col=0)
probs_df_test = pd.read_csv('sub_model_predictions_test.csv',index_col=0)

for tup in tuples_list:
    clf = tup[1]
    probs_array_train = clf.predict(train_projects[tup[0]])
    probs_array_test = clf.predict(test_projects[tup[0]])
    string =  tup[0]
    probs_df_train[string] = probs_array_train
    probs_df_test[string] = probs_array_test

# %%
probs_df_test.to_csv('sub_model_predictions_test.csv')
probs_df_train.to_csv('sub_model_predictions_train.csv')

# %% [markdown]
# ## 3.3 Text Analysis

# %% [markdown]
# ### 3.3.1 Framework

# %%
# Defining Cost Functions
def log_likelihood(clf, x, y):
    logPs = clf.predict_log_proba(x)
    return sum([logPs[i][1] for i in range(len(y)) if y[i] == 1]) + sum([logPs[i][0] for i in range(len(y)) if y[i] == 0])

def fraction_correct(clf, x, y):
    logPs = clf.predict_log_proba(x)
    guess = np.around(logPs)
    return np.mean(guess == y)

# Utilities for splitting up the dataframes into test and train sets
def gen_random(val):
    if random.random() < val:
        return False
    else:
        return True
    
def disjoint_sets(length, proportion=.25):
    include = [gen_random(proportion) for i in range(length)]
    exclude = [not(i) for i in include]
    return include, exclude

def prelim_split(df, field, proportion=.25):
    y='success'
    i, e = disjoint_sets(len(df), proportion)
    train = df[i]
    test = df[e]
    
    x = df[field]
    y = df['success']
    
    xtrain = train[field]
    xtest_final = test[field]
    ytrain = train['success']
    ytest_final = test['success']
    
    return x, y, xtrain, ytrain, xtest_final, ytest_final

def make_xy(x, y, vectorizer=None):
    text = x
    
    if vectorizer == None:
        vectorizer = CountVectorizer(min_df=0)

    vectorizer.fit(text)
    x = vectorizer.transform(text)
    #X = X.toarray()
    
    return x, y

# Utilities for plotting the predictions/calibration of a model
def ysigma(frac, n):
    return math.sqrt(frac*(1.0 - frac)/n)

def calibration_plot(clf, X, Y):
    nbins = 30
    proba = [row[1] for row in clf.predict_proba(X)]
    
    df        = pd.DataFrame({"proba": proba, "label": Y})
    df["bin"] = df.apply(lambda x: math.floor(x['proba'] * nbins), axis=1)
    
    bins      = df.groupby("bin")
    observed  = bins['label'].aggregate(np.mean).values
    predicted = bins['proba'].aggregate(np.mean).values
    bin_size  = bins['label'].aggregate(len).values
    
    sigmas    = [2*ysigma(observed[i], bin_size[i]) for i in range(len(bin_size))] # 95% confidence interval
    
    plt.errorbar(predicted, observed, yerr=np.vstack([sigmas, sigmas]))
    plt.plot([0,1], [0,1], color="r")
    plt.show()
    
    plt.hist(proba, color='orange')
    plt.show()

def train_score_display(vectorizer, clf, x, xtrain, ytrain, xtest, ytest, fit_params={}):
    vectorizer.fit(x)
    xtrain_v = vectorizer.transform(xtrain)
    xtest_v = vectorizer.transform(xtest)
    
    if 'weight' in fit_params:
        clf.fit(xtrain_v, ytrain, weight=fit_params['weight'])
    else:
        clf.fit(xtrain_v, ytrain)
    
    score = clf.score(xtest_v, ytest)
    calibration_plot(clf, xtest_v, ytest)
    
    return vectorizer, clf
# This is the code for the random exploration of the parameter space

def mult_dict(d, s):
    ans = {}
    for key in d.keys():
        ans[key] = d[key] * s
    return ans

def test_precision(params, sigmas, precision):
    for key in params.keys():
        target = params[key] * precision / 2.0
        if sigmas[key] * 2 > target:
            return False
    return True
        
def random_move(params, sigmas):
    ans = {}
    for key in params.keys():
        if random.random() < .5:
            ans[key] = -1
            while ans[key] <= 0:
                ans[key] = params[key] + random.gauss(0, sigmas[key])
        else:
            ans[key] = params[key]
            
    if params == ans:
        return random_move(params, sigmas)
    return ans

def random_optimization(model, params, sigmas, xtrain, ytrain, precision = .1):
    best_params = params
    i = 0
    
    while not test_precision(best_params, sigmas, precision):
        best_score  = model(best_params, xtrain, ytrain)
        new_params = random_move(best_params, sigmas)
        new_score  = model(new_params, xtrain, ytrain)
        
        if new_score > best_score:
            best_params = new_params
        else:
            sigmas = mult_dict(sigmas, .9)
        
        i += 1
        if i % 10 == 1:
            print i, best_params, best_score, sigmas
            
    return best_params, best_score

def nb_classifier(params, xtrain, ytrain):
    vectorizer = CountVectorizer(min_df = params['min_df'])
    vectorizer.fit(xtrain)
    X, Y = make_xy(xtrain, ytrain, vectorizer)
    clf = MultinomialNB(alpha = params['alpha'])
    return np.mean(cv.cross_val_score(clf, X, Y, scoring=log_likelihood))

def log_classifier(params, xtrain, ytrain):
    vectorizer = CountVectorizer(min_df = params['min_df'])
    vectorizer.fit(xtrain)
    X, Y = make_xy(xtrain, ytrain, vectorizer)
    clf = sklm.LogisticRegression(C=params['C'])
    return np.mean(cv.cross_val_score(clf, X, Y, scoring=log_likelihood))

def dt_classifier(params, xtrain, ytrain):
    vectorizer = CountVectorizer(min_df = params['min_df'])
    vectorizer.fit(xtrain)
    X, Y = make_xy(xtrain, ytrain, vectorizer)
    clf =  sktr.DecisionTreeClassifier()
    return np.mean(cv.cross_val_score(clf, X.toarray(), Y, scoring=tree_cost))

# %% [markdown]
# ### 3.3.2 Application of Framework

# %%
train_projects = pd.read_csv('train_projects.csv', index_col=0)
test_projects = pd.read_csv('test_projects.csv', index_col=0)

# %%
def logistic_text_model_step_1(df1,df2,df3):
    x, y, xtrain, ytrain, xtest, ytest = prelim_split(df1, 'text')
    best_params, score = random_optimization(log_classifier, {'min_df': .05, 'C':1}, {'min_df': .02, 'C':.5}, xtrain, ytrain)
    all_vec = CountVectorizer(min_df = best_params['min_df'])
    all_clf = sklm.LogisticRegression(C = best_params['C'])
    return all_vec, all_clf

def logistic_text_model_step_2(all_vec, all_clf,df1,df2,df3):
    
    texts = list(df2['text'].values) + list(df3['text'].values)
    all_vec.fit(texts)
    
    X = all_vec.transform(df2['text'])
    all_clf.fit(X,df2['success'])
    all_probs = all_clf.predict_proba(X)
    prob_1 = [p[1] for p in all_probs]
    X = all_vec.transform(df3['text'])
    all_probs = all_clf.predict_proba(X)
    prob_2 = [p[1] for p in all_probs]
    return prob_1 , prob_2

# %%
probs_df_train = pd.read_csv('sub_model_predictions_train.csv',index_col=0)
probs_df_test = pd.read_csv('sub_model_predictions_test.csv',index_col=0)
all_vec, all_clf = logistic_text_model_step_1(train_projects[:10000],train_projects,test_projects)
# Out:
# 1 {'C': 1, 'min_df': 0.008377682731829532} -1547.04971608 {'C': 0.5, 'min_df': 0.02}
# 11
#  {'C': 0.202254469726524, 'min_df': 0.02025009370785932} -1516.93265214 {'C': 0.2657205000000001, 'min_df': 0.010628820000000004}
# 21
#  {'C': 0.202254469726524, 'min_df': 0.022069487310384422} -1516.78791669 {'C': 0.10294556604732455, 'min_df': 0.004117822641892983}
# 31
#  {'C': 0.202254469726524, 'min_df': 0.020507839491676186} -1516.61931238 {'C': 0.039883221538436285, 'min_df': 0.0015953288615374516}
# 41
#  {'C': 0.22173462426062632, 'min_df': 0.021867855710127164} -1516.42421379 {'C': 0.01716841910146258, 'min_df': 0.0006867367640585033}
# 51
#  {'C': 0.22173462426062632, 'min_df': 0.021867855710127164} -1516.42421379 {'C': 0.005986257591281016, 'min_df': 0.00023945030365124078}

# %%
train_probs, test_probs = logistic_text_model_step_2(all_vec, all_clf,train_projects[:10000],train_projects,test_projects)

# %%
probs_df_train['text_probs'] = train_probs
probs_df_test['text_probs'] = test_probs
probs_df_train.to_csv('sub_model_predictions_train.csv')
probs_df_test.to_csv('sub_model_predictions_test.csv')

# %% [markdown]
# ### 3.3.3 Add Scores to sub_models dataframe

# %%
probs_df_train = pd.read_csv('sub_model_predictions_train.csv',index_col=0)
train_projects = pd.read_csv('train_projects.csv', index_col=0)
probs_df_train['success'] = [int(term == 'successful') for term in train_projects.state]
probs_df_train.to_csv('sub_model_predictions_train.csv')

probs_df_test = pd.read_csv('sub_model_predictions_test.csv',index_col=0)
test_projects = pd.read_csv('test_projects.csv', index_col=0)
probs_df_test['success'] = [int(term == 'successful') for term in test_projects.state]
probs_df_test.to_csv('sub_model_predictions_test.csv')

# %% [markdown]
# ## 3.4 - Are we overfitting?

# %% [markdown]
# Let's compare what sort of scores (log likelihood and fraction guessed) our model gets on the training and testing sets.

# %%
# score functions
def log_likelihood(proba, y):
    L = 0

    #fudged slightly so that things don't get wrecked by zero-probability events
    for i, term in enumerate(proba):
        proba[i] += 1./1000 if term == 0 else 0
        proba[i] -= 1./1000 if term == 1 else 0
    
    for index, value in enumerate(y):
        L += np.log(proba[index]) if value == 1 else np.log(1 - proba[index])
   
    return L 

def fraction_correct(proba, y):
    guess = np.array([round(term, 0) for term in proba])
    return np.mean(guess == y)

# function to print out the scores
def overfitting_print_out(train_predictions, test_predictions, train_successes, test_successes):
    fitting = {}
    for field in train_predictions.columns[1:-1]: #see if that's actually iterating through column names 
        fitting[field] = {
                          "train": {'log': log_likelihood(train_predictions[field], train_successes), 
                                    'guess': fraction_correct(train_predictions[field], train_successes)},
                          "test": {'log': log_likelihood(test_predictions[field], test_successes) * float(len(train_successes)) / len(test_successes), 
                                    'guess': fraction_correct(test_predictions[field], test_successes)}
                          }
        
        print "Field: " + field
        print "     On training data: "
        print "          Log likelihood: " + str(log_likelihood(train_predictions[field], train_successes))
        print "          Fraction Guessed: " + str(fraction_correct(train_predictions[field], train_successes))
        print "     On test data: "
        print "          (scaled) Log likelihood: " + str(log_likelihood(test_predictions[field], test_successes) * float(len(train_successes)) / len(test_successes))
        print "          Fraction Guessed: " + str(fraction_correct(test_predictions[field], test_successes))
        
    return fitting

def graph_overfitting(fitting):
    log_values = []
    guess_values = []
    for field in fitting.iterkeys():
        log_values.append(fitting[field]['test']['log'] - fitting[field]['train']['log'])
        guess_values.append(fitting[field]['test']['guess'] - fitting[field]['train']['guess'])

    
    lefts = np.array(range(len(fitting.keys()))) * 2. + 0.1
    
    fig = plt.figure()
    fig.set_size_inches(20.,5.)
    plt.bar(left=lefts, height=log_values, width=1.8)  
    plt.xlim(0, 2 * len(log_values))
    #plt.ylim(0,y_max)
    plt.xticks(lefts + 0.9, fitting.keys(), rotation=90, fontsize=8)
    remove_border()
    plt.title('log likelihood in test minus in train')
    plt.show()
    
    fig = plt.figure()
    fig.set_size_inches(20.,5.)
    plt.bar(left=lefts, height=guess_values, width=1.8)  
    plt.xlim(0, 2 * len(guess_values))
    #plt.ylim(0,y_max)
    plt.xticks(lefts + 0.9, fitting.keys(), rotation=90, fontsize=8)
    remove_border()
    plt.title('fraction guessed in test minus in train')
    plt.show()

# %%
# setup to print them out
train_predictions = pd.read_csv('sub_model_predictions_train.csv')
test_predictions = pd.read_csv('sub_model_predictions_test.csv')

# %%
#print out the scores
fitting = overfitting_print_out(train_predictions, test_predictions, train_successes, test_successes)
# Out:
# Field: project_length
#      On training data:
#           Log likelihood: -68184.1335023
#           Fraction Guessed: 0.572017073655
#      On test data:
#           (scaled) Log likelihood: -67853.2621641
#           Fraction Guessed: 0.583780479522
# Field: goal
#      On training data:
#           Log likelihood: -66276.7075627
#           Fraction Guessed: 0.600218383959
#      On test data:
#           (scaled) Log likelihood: -66337.6987143
#           Fraction Guessed: 0.60449636623
# Field: goal_dollars
#      On training data:
#           Log likelihood: -66370.3096888
#           Fraction Guessed: 0.586410561842
#      On test data:
#           (scaled) Log likelihood: -66335.0602533
#           Fraction Guessed: 0.584120084222
# Field: avg_title_word_length
#      On training data:
#           Log likelihood: -69067.8567554
#           Fraction Guessed: 0.552034941433
#      On test data:
#           (scaled) Log likelihood: -68965.5034337
# ...

# %%
graph_overfitting(fitting)

# %% [markdown]
# # Section 4 - Optimizing

# %% [markdown]
# ## 4.1 Framework

# %%
class CombinationFunction:    
    def __init__(self):
        pass
    
    def predict(self, parameters, prob_mat):
        return [self.combine(parameters, x) for x in prob_mat]
    
    def combine(self, parameters, x):
        raise NotImplementedError("Subclass must implement method")
        
    def gradient(self, parameters, x):
        raise NotImplementedError("Subclass must implement method")
        
    def dpdw(self, parameters, prob_mat):
        return np.matrix([self.gradient(parameters, row) for row in prob_mat])

class LinComb(CombinationFunction):
    def combine(self, parameters, probability_row):
        return sum([wi*xi for wi, xi in zip(parameters, probability_row)])
    
    def gradient(self, parameters, probability_row):
        return [probi for wi, probi in zip(parameters, probability_row)]

class LogComb(CombinationFunction):
    def combine(parameters, probability_row):
        return math.exp(linear_combination(parameters, probability_row))
    
    def gradient(self, parameters, probability_row):
        current = LinComb.combine(LinComb(), parameters, probability_row)
        return [probi * math.exp(current) for wi, probi in zip(parameters, probability_row)]
    
class MyComb(CombinationFunction):
    def combine(self, parameters, probability_row):
        return 1.0/(1.0 + -1*math.exp(LinComb.combine(LinComb(), parameters, [math.log(p/(1-p)) for p in probability_row])))
    
    def gradient(self, parameters, probability_row):
        current = self.combine(parameters, probability_row)
        return [-1*probi * math.exp(current) for wi, probi in zip(parameters, probability_row)]

def log_derivative(p, y):
    if y == 1:
        return 1.0 / p
    else:
        return -1.0 / (1 - p)

def ll_grad(pvector, ytrain):
    #print [log_derivative(p, y) for p,y in zip(pvector, ytrain)]
    return np.matrix([log_derivative(p, y) for p,y in zip(pvector, ytrain)])
    
def gradient(comb_func, parameters, prob_mat, ytrain):
    P    = comb_func.predict(parameters, prob_mat)
    dcdP = ll_grad(P, ytrain)
    dPdw = comb_func.dpdw(parameters, prob_mat)
    # print dcdP
    # print dPdw
    return dcdP * dPdw

def gradient_descent(mg, comb_func, parameters, xtrain, ytrain, gamma = .1):
    pm     = mg.prob_matrix(xtrain)
    params = np.matrix(parameters)
    grad   = gradient(comb_func, parameters, pm, ytrain)
    i      = 0
    
    while np.linalg.norm(grad) > 10:
        step   = (gamma / len(xtrain)) * grad  
        params += step 
        
        i += 1
        
        if i % 500 == 1:
            print i, ":  ", params, grad
            
        grad   = gradient(comb_func, params.tolist()[0], pm, ytrain)
    return params

# %%
def grad_descent(comb_func, parameters, xtrain_ps, ytrain, gamma = .01):
    pm     = xtrain_ps
    length = len(pm)
    params = np.matrix(parameters)
    grad   = gradient(comb_func, parameters, pm, ytrain)
    i      = 0
    
    while np.linalg.norm(grad) > 10:
        step   = (gamma / length) * grad  
        params += step 
        
        i += 1
        
        if i % 1 == 1:
            print i, ":  ", params, grad
            
        grad   = gradient(comb_func, params.tolist()[0], pm, ytrain)
    return params

# %% [markdown]
# ## 4.2 Run Weights Optimizer With all Params

# %%
predictions = pd.read_csv('sub_model_predictions_train.csv',index_col=0)
print len(predictions)
y = predictions['success']
predictions = predictions.drop('success',1)
predictions = predictions.drop('goal',1)
pmat = predictions.values
# Out:
# 100740

# %%
num_models = len(pmat[0])
best_params = grad_descent(LinComb(), [1./num_models for term in xrange(num_models)], pmat, y)

# %% [markdown]
# We ran this overnight on a different computer, and the output could not be merged. In the following cell I define the final output and the last output which had acceptable weights.

# %%
last_weighted_params = [ 0.15433351,  0.49148858, -0.16720813, -0.21448514, -0.19872129, -0.22431353,
  -0.22678009,  0.19120896, -0.23321843,  0.99948254, -0.23321843, -0.11623803,
   0.75762533]
last_run_params = [-6.09740802, -2.87457265, -6.83618694, -8.92029167, -8.03257479, -8.83409137,
  -8.68089443, -6.16683421, -7.03926678, -6.58283562, -7.03926678, -8.04141512,
   0.14556938]

# %% [markdown]
# ## 4.3 Run Weights Optimizer With leading Params

# %%
predictions = pd.read_csv('sub_model_predictions_train.csv',index_col=0)
print len(predictions)
y = predictions['success']
predictions = predictions.drop('success',1)
predictions = predictions.drop('goal',1)
cols_to_remove = ['avg_title_word_length', 'percent_caps_in_title', 
          'percent_caps_in_blurb', 'title_length', 'blurb_length', 'country', 
           'currency', 'website_overall']
for col in cols_to_remove:
    predictions = predictions.drop(col, axis=1)
print predictions.columns
pmat = predictions.values
# Out:
# 100740
# Index([project_length, goal_dollars, category, location_name, text_probs], dtype=object)

# %%
num_models = len(pmat[0])
best_params = grad_descent(LinComb(), [1./num_models for term in xrange(num_models)] , pmat, y)
# Out:
# 1 :   [[ 0.20005046  0.20036518  0.20028743  0.20089978  0.20066675]] [[  508.3627522   3678.79854851  2895.54777792  9064.40096362
#    6716.82953197]]
# 51
#  :   [[ 0.18996305  0.20544052  0.20171937  0.23220898  0.22097196]] [[-3284.50557161  -290.6956636  -1008.32614777  4893.12487746
#    2770.67110094]]
# 101
#  :   [[ 0.17211415  0.2023372   0.19501853  0.25428322  0.23287775]] [[-3734.54546062  -779.07769792 -1514.47988724  4187.19860566
#    2204.60856495]]
# 151
#  :   [[ 0.1535378   0.19837613  0.18733913  0.27443339  0.24350178]] [[-3728.63513943  -793.52056594 -1556.20614972  3961.9455421   2101.62646285]]
# 201
#  :   [[ 0.13519483  0.194554    0.179662    0.29370229  0.25382712]] [[-3661.39527213  -744.82022132 -1534.83481798  3810.22518785
#    2063.07170516]]
# 251
#  :   [[ 0.11720907  0.19099634  0.17211659  0.31226687  0.2639908 ]] [[-3587.54892636  -689.90102661 -1506.04606703  3674.87338523
#    2033.52770162]]
# 301
# ...

# %%
small_params = [-0.60642544, 0.30890851, -0.25184834, 0.8074514, 0.77118529]

# %% [markdown]
# After trial 7401, we're at values of [-0.60642544  0.30890851 -0.25184834  0.8074514   0.77118529]  and gradients of [-13.68194896  10.37812515   8.63654236  -6.70985199   1.39403842]
#
# The weights sum to 1.02927142, which is reassuring, though it's somewhat disconcerting that two of their values are negative - that would suggest that the other paramters just make absolutely more accurate predictions WAIT ACTUALLY IDK WHAT THIS MEANS.... TALK TO PEOPLE

# %% [markdown]
# ## 4.4 - Assembling resulting models

# %%
# get the predicted values from the original predictions and the weightings we found
def weighted_predict(pmat, weights, y):
    
    weighted_prediction = np.zeros(y.size)
        
    for col, weight in enumerate(weights):
        weighted_prediction += weight * pmat[:, col]
        
    #if anything is predicted at above one or below 0, send back into the unit interval
    for i, term in enumerate(weighted_prediction):
        if term < 0:
            weighted_prediction[i] = 0
        if term > 1:
            weighted_prediction[i] = 1
            
    print 'log_like: ' +  str(log_likelihood(weighted_prediction, y))
    print 'fraction-guessed: ' +  str(fraction_correct(weighted_prediction, y))
        
    return weighted_prediction

#cost functions
def log_likelihood(proba, y):
    L = 0
    
    #fudged slightly so that things don't get wrecked by zero-probability events (see explanation in markdown above)
    for i, term in enumerate(proba):
        proba[i] += 1./1000 if term == 0 else 0
        proba[i] -= 1./1000 if term == 1 else 0
        
    true_logs = np.log(proba)
    false_logs = np.log(1 - proba)
    
    for index, value in enumerate(y):
        L += true_logs[index] if value == 1 else false_logs[index]
            
    return L

def fraction_correct(proba, y):
    guess = np.around(proba)
    return np.mean(guess == y)

# %%
print weighted_predict(pmat, small_params, y)
# Out:
# log_like: -64553.2850157
# fraction-guessed: 0.589239626762
# [ 0.50960897  0.59174635  0.32512426 ...,  0.20188552  0.26141345
#   0.64001681]

# %% [markdown]
# # Section 5 - Redo Models to Maximize Number Guessed Correctly

# %% [markdown]
# This is going to be all the almost-same code from earlier, but we're just going to optimize for the fraction-guessed-correct metric instead of log-likelihood. Fraction-guessed-correct might not be as meaningful, but it's a lot easier to understand, so this is cool.

# %% [markdown]
# ## 5.1 - Numerical models

# %% [markdown]
# Note - you have to rerun the big cell defining functions in 3.1.1 before this will work

# %%
# get the training projects and the test projects
train_projects = pd.read_csv('train_projects.csv', index_col = 0)
test_projects = pd.read_csv('test_projects.csv', index_col = 0)

# %%
# this makes a convenient dataframe that contains the numeric fields we've modelled
def make_numeric(df):
    numeric_df = pd.DataFrame({'blank' : df['creator_id'].map(lambda x: 0)})
    numeric_df['title_length'] = [float(len(str(name))) for name in df['project_name']]
    numeric_df['blurb_length'] = [float(len(str(blurb))) for blurb in df['blurb']]
    numeric_df['avg_title_word_length'] = [np.mean([float(len(word)) for word in str(title).split(' ')]) for title in df['project_name']]
    numeric_df['percent_caps_in_title'] = [np.mean([x.isupper() for x in str(text)]) for text in df['project_name']]
    numeric_df['percent_caps_in_blurb'] = [np.mean([x.isupper() for x in str(text)]) for text in df['blurb']]
    numeric_df['goal_dollars'] = df.goal_dollars
    numeric_df['project_length'] = df.project_length
    numeric_df['goal'] = df.goal
    numeric_df['successful'] = [int(item =='successful') for item in df.state]
    numeric_df = numeric_df.drop('blank',1)
    
    return numeric_df

# %%
# get the numeric fields, for the test and the training
train_numeric = make_numeric(train_projects)
test_numeric = make_numeric(test_projects)

# %%
# jsut some info on how to make the plots
def log_values(string):
    return False if 'caps' in string else True

# %%
# function to run the numerical modelling code, printing out graphs and returning predictions
def run_numerical_model(col):
    probs_df_train = pd.read_csv('sub_model_predictions_train_fraction_guessed.csv',index_col=0)
    probs_df_test = pd.read_csv('sub_model_predictions_test_fraction_guessed.csv',index_col=0)
    num_train, num_test = numerical_model(
                                      train_numeric[col],
                                      train_numeric['successful'],
                                      test_numeric[col],
                                      test_numeric['successful'],
                                      col,
                                      fraction_correct, 
                                      10000, 
                                      log_x = log_values(col), 
                                      distr_log_y = True)
    probs_df_train[col] = num_train
    probs_df_test[col] = num_test
    probs_df_train.to_csv('sub_model_predictions_train_fraction_guessed.csv')
    probs_df_test.to_csv('sub_model_predictions_test_fraction_guessed.csv')

# %%
# set up dataframes to save our predictions into
probs_df_train = pd.DataFrame({'blank' : train_projects['creator_id'].map(lambda x: 0)})
probs_df_train.to_csv('sub_model_predictions_train_fraction_guessed.csv')
probs_df_test = pd.DataFrame({'blank' : test_projects['creator_id'].map(lambda x: 0)})
probs_df_test.to_csv('sub_model_predictions_test_fraction_guessed.csv')

# %%
column_names = ['project_length', 'goal', 'goal_dollars','avg_title_word_length',
                     'percent_caps_in_title', 'percent_caps_in_blurb','title_length','blurb_length']

# %%
run_numerical_model(column_names[0])
# Out:
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, n_neighbors=243, p=2,
#           warn_on_equidistant=False, weights=uniform)
# log_likelihood: -9920.75813178
# fraction guessed correctly: 0.591455545745

# %%
run_numerical_model(column_names[1])
# Out:
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, n_neighbors=243, p=2,
#           warn_on_equidistant=False, weights=uniform)
# log_likelihood: -9619.5178318
# fraction guessed correctly: 0.60551518033

# %%
run_numerical_model(column_names[2])
# Out:
# bestKNeighborsRegressor(algorithm=auto, leaf_size=30, n_neighbors=243, p=2,
#           warn_on_equidistant=False, weights=uniform)
# log_likelihood: -9609.37572153
# fraction guessed correctly: 0.612035590573

# %%
run_numerical_model(column_names[3])
# Out:
# bestLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty=l1, random_state=None, tol=0.0001)
# log_likelihood: -45696.0064724
# fraction guessed correctly: 0.550770902669

# %%
run_numerical_model(column_names[4])
# Out:
# bestLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty=l1, random_state=None, tol=0.0001)
# log_likelihood: -45910.1158705
# fraction guessed correctly: 0.548665353528

# %%
run_numerical_model(column_names[5])
# Out:
# bestLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty=l1, random_state=None, tol=0.0001)
# log_likelihood: -45426.643036
# fraction guessed correctly: 0.55341981933

# %%
run_numerical_model(column_names[6])
# Out:
# bestLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty=l1, random_state=None, tol=0.0001)
# log_likelihood: -45426.643036
# fraction guessed correctly: 0.55341981933

# %%
run_numerical_model(column_names[7])
# Out:
# bestLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty=l1, random_state=None, tol=0.0001)
# log_likelihood: -45426.643036
# fraction guessed correctly: 0.55341981933

# %%
# clean up the dataframes / csvs we saved the predictions into
probs_df_train = pd.read_csv('sub_model_predictions_train_fraction_guessed.csv',index_col=0)
probs_df_train = probs_df_train.drop('blank', 1)
probs_df_train.to_csv('sub_model_predictions_train_fraction_guessed.csv')

probs_df_test = pd.read_csv('sub_model_predictions_test_fraction_guessed.csv',index_col=0)
probs_df_test = probs_df_test.drop('blank', 1)
probs_df_test.to_csv('sub_model_predictions_test_fraction_guessed.csv')

# %% [markdown]
# How did these do compared to the classifiers we made earlier - in terms of fraction_guessed_right score on the test set?
#
# For the first three fields (project length and the converted and unconverted goal amounts), we do about the same.
#
# In the later fields, we do a little bit better than before, but for a silly reason: we were doing very poorly before since we did a better job this time by just guessing 0 for everything. Haha.

# %% [markdown]
# ## 5.2 - Categorical Models

# %% [markdown]
# Fortunately, the same strategy we used to choose the optimal categorical model for log likelihood also chooses the optimal model for fraction-guessed-correct. Namely, we guess that something in some category succeeds with probaility eqaul to the fraction of things in the traingin set in that category that succeeded.
#
# So we'll just add on the categorical predictions to our fraction_guessed predictions.

# %%
#get the old predictions
old_df_train = pd.read_csv('sub_model_predictions_train.csv',index_col=0)
old_df_test = pd.read_csv('sub_model_predictions_test.csv',index_col=0)

#open the new ones
probs_df_train = pd.read_csv('sub_model_predictions_train_fraction_guessed.csv',index_col=0)
probs_df_test = pd.read_csv('sub_model_predictions_test_fraction_guessed.csv',index_col=0)

# copy over the relevant parts
groupings = ['category','country','location_name','currency','website_overall', 'success']
for grouping in groupings:
    probs_df_train[grouping] = old_df_train[grouping]
    probs_df_test[grouping] = old_df_test[grouping]

# %%
#save
probs_df_train.to_csv('sub_model_predictions_train_fraction_guessed.csv')
probs_df_test.to_csv('sub_model_predictions_test_fraction_guessed.csv')

# %% [markdown]
# ## 5.3 - Text-based Models

# %% [markdown]
# Note: Have to run 3.3.1 before this will work (gets helper functions)

# %%
#here is the framework code I need
def new_log_classifier(params, xtrain, ytrain):
    vectorizer = CountVectorizer(min_df = params['min_df'])
    vectorizer.fit(xtrain)
    X, Y = make_xy(xtrain, ytrain, vectorizer)
    clf = sklm.LogisticRegression(C=params['C'])
    return np.mean(cv.cross_val_score(clf, X, Y, scoring=fraction_correct))


def logistic_text_model_step_1(df1,df2,df3):
    x, y, xtrain, ytrain, xtest, ytest = prelim_split(df1, 'text')
    best_params, score = random_optimization(new_log_classifier, {'min_df': .05, 'C':1}, {'min_df': .02, 'C':.5}, xtrain, ytrain)
    all_vec = CountVectorizer(min_df = best_params['min_df'])
    all_clf = sklm.LogisticRegression(C = best_params['C'])
    return all_vec, all_clf

def logistic_text_model_step_2(all_vec, all_clf,df1,df2,df3):
    
    texts = list(df2['text'].values) + list(df3['text'].values)
    all_vec.fit(texts)
    
    X = all_vec.transform(df2['text'])
    all_clf.fit(X,df2['success'])
    all_probs = all_clf.predict_proba(X)
    prob_1 = [p[1] for p in all_probs]
    X = all_vec.transform(df3['text'])
    all_probs = all_clf.predict_proba(X)
    prob_2 = [p[1] for p in all_probs]
    return prob_1 , prob_2

# %% [markdown]
# Now apply these functions:

# %%
#get the projects
train_projects = pd.read_csv('train_projects.csv', index_col=0)
test_projects = pd.read_csv('test_projects.csv', index_col=0)

# %%
probs_df_train = pd.read_csv('sub_model_predictions_train_fraction_guessed.csv',index_col=0)
probs_df_test = pd.read_csv('sub_model_predictions_test_fraction_guessed.csv',index_col=0)
all_vec, all_clf = logistic_text_model_step_1(train_projects[:10000],train_projects,test_projects)
# Out:
# 1 {'C': 1, 'min_df': 0.05} 0.0 {'C': 0.45, 'min_df': 0.018000000000000002}
# 11
#  {'C': 1, 'min_df': 0.05} 0.0 {'C': 0.15690529804500009, 'min_df': 0.006276211921800004}
# 21
#  {'C': 1, 'min_df': 0.05} 0.0 {'C': 0.05470949456575622, 'min_df': 0.002188379782630249}

# %%
train_probs, test_probs = logistic_text_model_step_2(all_vec, all_clf,train_projects[:10000],train_projects,test_projects)

# %%
probs_df_train['text_probs'] = train_probs
probs_df_test['text_probs'] = test_probs
probs_df_train.to_csv('sub_model_predictions_train_fraction_guessed.csv')
probs_df_test.to_csv('sub_model_predictions_test_fraction_guessed.csv')

# %% [markdown]
# ## 5.4 - Optimizing Over Models

# %% [markdown]
# Note: make sure to run 4.1 and 4.2 before this.

# %%
So the random probing function should do something like pick 20 random numbers between 0 and 1 and then scale so they add to one. 
NOT CLEAR HOW TO DO THAT PART
Then get the predictions based on that, evaluate the score.
DO this for some number of trials or until some condiction is met

# %%
#cost function
def frac_cost(x, y):
    guess = np.around(x)
    return np.mean(guess == y)

def log_cost(proba, y):
    L = 0
    
    #fudged slightly so that things don't get wrecked by zero-probability events (see explanation in markdown above)
    for i, term in enumerate(proba):
        proba[i] += 1./1000 if term == 0 else 0
        proba[i] -= 1./1000 if term == 1 else 0
        
    true_logs = np.log(proba)
    false_logs = np.log(1 - proba)
    
    for index, value in enumerate(y):
        L += true_logs[index] if value == 1 else false_logs[index]
            
    return L

# generates array of weights (summing to 1)
def generate_weights(num):
    weights = 2 * (np.random.rand(num) - 0.5)
    return weights / sum(weights)

# generates array of weights that can be negative (summing to 1)
def generate_weights_alt(num):
    weights = 1. / 0.9 * (np.random.rand(num) - 0.1)
    return weights / sum(weights)

#generates a weighted prediction
def weighted_predict(pmat, weights):
    
    weighted_prediction = np.zeros(y.size)
        
    for col, weight in enumerate(weights):
        weighted_prediction += weight * pmat[:, col]
        
    return weighted_prediction

# performs the random sampling
def random_sampling_optimizer(pmat, y, generator, trials):
    
    scores = []
    weight_store = []
    
    for term in xrange(trials):
        
        if term % 1000 == 0:
            print term
        
        weights = generator(pmat.shape[1])
        
        weighted_prediction = weighted_predict(pmat, weights)
        
        score = frac_cost(weighted_prediction, y)
        
        scores.append(score)
        weight_store.append(weights)
        
    print max(scores)
    final_weights = weight_store[scores.index(max(scores))]
    print final_weights
    print 'log score: ' + str(log_cost(weighted_predict(pmat, final_weights), y))

# %%
predictions = pd.read_csv('sub_model_predictions_train_fraction_guessed.csv',index_col=0)
print len(predictions)

y = predictions['success']

cols_to_remove = ['success', 'goal', 'avg_title_word_length', 'percent_caps_in_title', 
          'percent_caps_in_blurb', 'title_length', 'blurb_length', 'country', 
           'currency', 'website_overall']
for col in cols_to_remove:
    predictions = predictions.drop(col, axis=1)

pmat = predictions.values
# Out:
# 100740

# %%
for i in xrange(5):
    values = [0,0,0,0,0]
    values[i] = 1
    weighted_prediction = weighted_predict(pmat, values)
    print frac_cost(weighted_prediction, y)
# Out:
# 0.611901925749
# 0.583631129641
# 0.616934683343
# 0.630236251737
# 0.600585666071

# %%
weighted_prediction = weighted_predict(pmat, [1./2, 0, 0, 1./2, 0])
print frac_cost(weighted_prediction, y)
# Out:
# 0.669684335914

# %%
random_sampling_optimizer(pmat, y, generate_weights, 10000)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 0.695840778241
# [4325, array([ 0.257771  ,  0.08369625,  0.20635234,  0.28497648,  0.16720394])]

# %%
random_sampling_optimizer(pmat, y, generate_weights, 10000)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 0.696456223943
# [6454, array([ 0.29178067,  0.07971606,  0.21230992,  0.25690279,  0.15929057])]

# %%
random_sampling_optimizer(pmat, y, generate_weights, 10000)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 0.696217986897
# [97, array([ 0.29748129,  0.07268679,  0.20137221,  0.26061247,  0.16784724])]

# %%
random_sampling_optimizer(pmat, y, generate_weights, 10000)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 0.695622394282
# [ 0.3490343   0.0155845   0.18409467  0.30238303  0.1489035 ]
# log score: -61941.6584864

# %%
random_sampling_optimizer(pmat, y, generate_weights_alt, 10000)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 0.696158427635
# [2692, array([ 0.28988071,  0.03764062,  0.22780511,  0.27872647,  0.16594709])]

# %%
random_sampling_optimizer(pmat, y, generate_weights_alt, 10000)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 0.696118721461
# [3020, array([ 0.28432012,  0.06468653,  0.21980365,  0.26570848,  0.16548121])]

# %%
def frac_cost(x, y):
    guess = np.around(x)
    return np.mean(guess == y)

def fake_gradient(comb_func, parameters, pm, ytrain, step=.00001):
    ans = [0 for i in parameters]
    for i in range(len(parameters)):
        old = frac_cost(comb_func.predict(parameters, pm), y)
        parameters[i] += step
        new = frac_cost(comb_func.predict(parameters, pm), y)
        parameters[i] -= step
        ans[i] = 100000 * (new - old)   
    return ans

def fake_grad_desc(comb_func, parameters, xtrain_ps, ytrain, gamma=.01):
    pm     = xtrain_ps
    params = np.matrix(parameters)
    plength = len(parameters)
    length = len(xtrain_ps)
    grad   = fake_gradient(comb_func, parameters, pm, ytrain)
    i      = 0
    
    while True: #np.linalg.norm(grad) > 0.01 * plength:
        step   = (gamma / length) * np.array(grad)  
        params += step 
        i += 1
        
        if i % 1 == 1:
            print i, ":  ", params, grad
            
        grad = fake_gradient(comb_func, params.tolist()[0], pm, ytrain)
    return params

def grad_descent(comb_func, parameters, xtrain_ps, ytrain, gamma = .01):
    pm     = xtrain_ps
    length = len(pm)
    params = np.matrix(parameters)
    grad   = gradient(comb_func, parameters, pm, ytrain)
    i      = 0
    
    while np.linalg.norm(grad) > 10:
        step   = (gamma / length) * grad  
        params += step 
        
        i += 1
        
        if i % 50 == 1:
            print i, ":  ", params, grad
            
        grad   = gradient(comb_func, params.tolist()[0], pm, ytrain)
    return params

# %%
predictions = pd.read_csv('sub_model_predictions_train_fraction_guessed.csv',index_col=0)
print len(predictions)
y = predictions['success']
predictions = predictions.drop('success',1)
predictions = predictions.drop('goal',1)
pmat = predictions.values
print pmat.shape
# Out:
# 100740
# (100740, 13)
