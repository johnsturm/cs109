# %%
import requests
import re

def get_titles(year, month, day):
    url = "http://www.kickspy.com/projects/find?Keywords=&Settings.ExpandStatus=true&AnyStatus=true&AllCategories=true&Settings.ExpandDates=true&StartedAfter=" + year + "%2F" + month + "%2F" + day + "&StartedBefore=" + year + "%2F" + month + "%2F" + day + "&SortBy=0"
    
    response = requests.get(url)
    text = response.text
    
    titles = re.findall(r'">(.*)<\/a><\/h3>', text)
    return titles

get_titles("2013", "11", "12")
get_titles("2013", "11", "13")
# Out:
# [u'The MS Manifesto: Thriving In Denial',
#  u'SEED: The Untold Story - The Final Push',
#  u'SEED: The Untold Story - The Final Push',
#  u'&#39;For $500 I will recreate an onion after cooking it&#39;',
#  u'Collective, Dream Arts Journal Launch',
#  u'Super Heroes - Stickers / Decals / Tees / Prints',
#  u'Blood Sweat and Tears: Certified Organic Cotton Zip Towel',
#  u'3 Minute RPG',
#  u'Demon X Soul',
#  u'The Neverending Game',
#  u'&#39;Love Notes&#39; short film',
#  u'Tiny Shops Burgers - Education via Gamification',
#  u'&quot;A Bouquet From The Cat&quot; ~ A Whimsical Art Project',
#  u'Viking Horde: A Paper-craft Game',
#  u'Albie Merani Book One (Canceled)',
#  u'The Arksville Homicides - World&#39;s First CG Horror Web-Series',
#  u'Be part of the Magic of Labyrinth Rocks - short film project',
#  u'Planet Miner Card Game',
#  u'Bedlam - a thoroughly uncooperative card game',
#  u'BEAUTIFUL TREE, SEVERED ROOTS doc film needs licensing',
#  u'2013 FTC Team 7042 Robot',
#  u'EELCREEK  - A ( reverse) FISHING GAME FOR MOBILE',
#  u'Sustainable Food Pavilion Architectural Design-Expo 2015',
#  u'Notolio',
#  u'The Civilization of Light &amp; Dark',
#  u'This is the new Big Pop Star, Australias got talent 2013,',
#  u'Trainz Simulator: A New Era - Create, Drive, Operate, Share',
#  u'Rahim&#39;s new 14 song record -- Born on a Sunday!!',
#  u'United States Historical Landmarks Database',
#  u'Mars Opera - A Comical Musical',
#  u'$50,000 AND A SPY LOSES HIS KNICKERS - VERY EXPLICITLY',
#  u'NINJA SPHERE: Next Generation Control of Your Environment',
#  u'Mystery Jars: Time in a Bottle',
#  u'PINK AND BLUE',
#  u'endplay',
#  u'Never Lose Faith, Book I am writing',
#  u'OUR VOICES - An Art Book Celebrating Multi-Cultural Beauty',
#  u'Space Station Alpha',
#  u'Cheestroyer Cheeseburger Glow in the Dark Vinyl Toy',
#  u'Steam in the Willows',
#  u'A Son&#39;s Breast Cancer Story',
#  u'Restaurant Day Worcester: Pop-Up Cafe',
#  u'&quot;The Lonely&quot; photography show',
#  u'Mate Clothing Co',
#  u'OUTLAW INC.&#39;s New Album &quot;667 beyond evil,baby!&quot;',
#  u'IMREAL CLOTHING',
#  u'Don&#39;t Sit On The Stairs EP Stephentodd Tracy &quot;The Coyote&quot;',
#  u'&quot;Everything is Possible&quot; India Collection (fun watercolours)',
#  u'ZoomerangKidz Adventures: Entertainment Broccoli for Kids',
#  u'Jumping Spider',
#  u'SwiftBot WP: a rugged, modular, and waterproof quadcopter',
#  u'READ ONLY MEMORIES: A Tribute to 90&#39;s Adventure Games',
#  u'The 3X3 Project',
#  u'Proper Audio - PA1: Mountable Bluetooth Speaker',
#  u'SpaceUp NZ - a space unconference',
#  u'The Chrysanthemum Trilogy: Transition',
#  u'DJ Soko&#39;s (The Left) first full length album: DOMINO EFFECT',
#  u'D.I.Y Cardboard Toys',
#  u'Beneath Our Own Immensity / The Film',
#  u'One Forest Day',
#  u'Theater production of &quot;The Agony of Colin Powell&quot;',
#  u'&quot;Epic Voyage&quot; Book: Miraculous TRUE STORY 2004 Tsunami Hero',
#  u'Hong Kong Phooey for Saturday Morn&#39;in Mayem V.3 and Mugen!',
#  u'Northern Oak: The New Album',
#  u'OUT LOUD | An Unconventional Documentary Movie',
#  u'&quot;My Gal, the Zombie&quot; Graphic Novel &amp; Soundtrack',
#  u'DADDY - a new film based on the hit play',
#  u'SEE: What does the cost of your body cost your soul?',
#  u'Draw Destruction, the epic drawing battle !',
#  u'The World Map by Sand Grains',
#  u'Volunteer Firefighter Life',
#  u'Micro Python: Python for microcontrollers',
#  u'Collectable CD&#39;s of &#39;The Way I See the World&#39; by Esoligh',
#  u'The Dalmatian Plantation',
#  u'Laserpod 2 - a little laser in your life',
#  u'JUST SAY HI! Brady Rymer&#39;s new album for families that ROCK.',
#  u'The Happy Life Story',
#  u'1979 REVOLUTION: Black Friday',
#  u'A Moment to Move - a short film',
#  u'GoPlug - Powering Mobility',
#  u'Peatree Bojangles Oxford Art Fair',
#  u'Documentary about Shelter Animals (Canceled)',
#  u'Publishing Prayer Poetry for those who have been there.',
#  u'Tonya&#39;s Cute by Design- Our Own Yarn Line',
#  u'Big City Dream Show',
#  u'Color It Success',
#  u'Bringing Flavour Cafe Back to Life',
#  u'No Longer Human',
#  u'The Lily Ella Mission',
#  u'&quot;I Matter&quot; Project at Suffolk County Community College',
#  u'The Push',
#  u'Looly&#39;s Fine Pearls : The &quot;0 COMPROMISE FOOD&quot;',
#  u'Hard Rock Havana',
#  u'My first album',
#  u'Finally do something about bad parking',
#  u'Nalibeli: Helping government work in Nepal',
#  u'Rhizosphere farm - Help us put down roots!',
#  u'MetalPress Drink Coasters',
#  u'The Slaughter',
#  u'Changing Lives in America',
#  u'Sip: Bigger and Boozier!',
#  u'Polymer Clay Journals',
#  u'The Eye Collector - DC Lennox Series Book 1',
#  u'100 Unique Ornamental Dolls',
#  u'Publish in English a masterpiece and donate many e-books',
#  u'FHG - Out Of This World LAN',
#  u'Trading our tractors for Horses',
#  u'The Permaculture Orchard : Beyond Organic',
#  u'&#39;We Go To The Gallery&#39;',
#  u'Enrapture Yourself In Chocolate!!!',
#  u'Paroxysm Temporal',
#  u'Let&#39;s Play - Your Indie PlayStation Magazine',
#  u'MAKE THE GALACTIC SUPERSTARS MOVIE (Canceled)',
#  u'Michele&#39;s Simply Sweet Cake Pop Extravaganza',
#  u'lego lamp company',
#  u'Previously... Art Exhibition',
#  u'Hold Out Hope &quot;Bright Lights, Dark Places&quot; Album Project',
#  u'New From First To Last Record!',
#  u'Advanced Bestiary for the Pathfinder RPG',
#  u'Muckville: a memoir of the public policy life of a farmer!',
#  u'ZACH HECKENDORF - THE NEW ALBUM',
#  u'The Chinese Punk Project - A Documentary (Canceled)',
#  u'ZIP TRAY: bicycle carry tray',
#  u'Queen Bee Coffee Company: Serving the Thirsty',
#  u'Visions of a Black Life (Documentary&amp;Album)',
#  u'L Cookies: Organic &amp; Made with Love',
#  u'A Familiar Fire: Stewart Francke&#39;s new cd project',
#  u'The Places We Ignore']
